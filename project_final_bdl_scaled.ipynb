# %%
import numpy as np
import pandas as pd
import pickle
import seaborn as sns

# %%
pd.__version__
# Out:
# '2.2.1'

# %%
RANDOM_STATE = 42

# %% [markdown]
# ## 1. Prepare data
#
# ### Merge 3 data frames into single one by abon_id

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

def prepare_related_data(columns: list, index_column: str, df: pd.DataFrame) -> pd.DataFrame:
    """
    Related data will be processed in the same way:
    - group by `index_column`
    - sum all columns
    - apply log1p to all columns except `index_column`
    """
    col_to_fetch = columns + [index_column]
    res = df[col_to_fetch].groupby(index_column).sum()
    res = res[columns].apply(np.log1p)
    return res


def prepare_data(train: pd.DataFrame, dpi: pd.DataFrame, bnum: pd.DataFrame) -> pd.DataFrame:
    """
    Prepare data for training
    """
    dpi_columns = ['SUM_of_Duration_sec','SUM_of_Volume_kb','SUM_of_Count_events','MAX_of_day_cnt']
    dpi_index_column = 'abon_id'

    bnum_columns = ['call_cnt_out','call_cnt_in','call_dur_out','call_dur_in','cnt_sms_out','cnt_sms_in']
    bnum_index_column = 'abon_id'

    df_train_dpi_agg = prepare_related_data(dpi_columns, dpi_index_column, dpi)
    df_train_bnum_agg = prepare_related_data(bnum_columns, bnum_index_column, bnum)
    # let's merge all dataframes
    # merge bnum dataframe
    df_train = train.merge(df_train_bnum_agg, on='abon_id', how='left')

    # merge dpi dataframe
    df_train = df_train.merge(df_train_dpi_agg, on='abon_id', how='left')

    # fill missings for dpi_columns, bnum_columns
    df_train.fillna({col: df_train[col].median() for col in dpi_columns + bnum_columns}, inplace=True)
    return df_train


# Function for comparing different approaches
def score_dataset(X_train, X_valid, y_train, y_valid):
    model = RandomForestRegressor(n_estimators=100, random_state=RANDOM_STATE)
    model.fit(X_train, y_train)
    preds = model.predict(X_valid)
    return mean_absolute_error(y_valid, preds)


def get_score(df_train: pd.DataFrame, target_column: str = 'target') -> float:
    """
    Get score for the given dataframes
    """
    acopy = df_train.copy()
    X, y = acopy.drop(target_column, axis=1), acopy[target_column]
    X_train, X_val, y_train, y_val= train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE)

    return score_dataset(X_train, X_val, y_train, y_val)


def get_feature_importance(df_train: pd.DataFrame =  None, target_column: str = 'target', estimator=RandomForestRegressor) -> pd.DataFrame:
    """
    Get feature importance for the given dataframes
    """
    acopy = df_train.copy()
    X, y = acopy.drop(target_column, axis=1), acopy[target_column]
    return estimate_feature_importance(X, y, estimator)


def estimate_feature_importance(X, y, estimator) -> pd.DataFrame:
    model = estimator(random_state=RANDOM_STATE)
    model.fit(X, y)
    return pd.DataFrame(data=model.feature_importances_, index=X.columns, columns=['importance']).sort_values(by='importance', ascending=False)


def drop_columns_with_nulls(frame: pd.DataFrame, threshold: float = 0.7) -> pd.DataFrame:
    """
    Drop columns with more than threshold % of nulls
    """
    return frame.dropna(thresh=threshold*frame.shape[0], axis=1)



def impute_dataset(X, y) -> pd.DataFrame:
    """
    Impute dataset
    """
    simple_impute = SimpleImputer(missing_values=np.nan, add_indicator=True, strategy='constant', fill_value=0)
    imputed = simple_impute.fit_transform(X, y)
    # Extract the indicator columns
    indicator = simple_impute.indicator_
    indicator_columns = indicator.get_feature_names_out(input_features=X.columns)
    # Reconstruct the DataFrame with the original columns and indicator columns
    new_columns = list(X.columns) + list(indicator_columns)
    return pd.DataFrame(imputed, columns=new_columns, index=X.index)



## Dataset scoring

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

def prepare_related_data(columns: list, index_column: str, df: pd.DataFrame) -> pd.DataFrame:
    """
    Related data will be processed in the same way:
    - group by `index_column`
    - sum all columns
    - apply log1p to all columns except `index_column`
    """
    col_to_fetch = columns + [index_column]
    res = df[col_to_fetch].groupby(index_column).sum()
    res = res[columns].apply(np.log1p)
    return res


# Function for comparing different approaches
def score_dataset(X_train, X_valid, y_train, y_valid):
    model = RandomForestRegressor(n_estimators=100, random_state=RANDOM_STATE)
    model.fit(X_train, y_train)
    preds = model.predict(X_valid)
    return mean_absolute_error(y_valid, preds)


def get_score(df_train: pd.DataFrame, target_column: str = 'target') -> float:
    """
    Get score for the given dataframes
    """
    acopy = df_train.copy()
    X, y = acopy.drop(target_column, axis=1), acopy[target_column]
    X_train, X_val, y_train, y_val= train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE)

    return score_dataset(X_train, X_val, y_train, y_val)


def get_feature_importance(df_train: pd.DataFrame =  None, target_column: str = 'target', estimator=RandomForestRegressor) -> pd.DataFrame:
    """
    Get feature importance for the given dataframes
    """
    acopy = df_train.copy()
    X, y = acopy.drop(target_column, axis=1), acopy[target_column]
    return estimate_feature_importance(X, y, estimator)


def estimate_feature_importance(X, y, estimator) -> pd.DataFrame:
    model = estimator(random_state=RANDOM_STATE)
    model.fit(X, y)
    return pd.DataFrame(data=model.feature_importances_, index=X.columns, columns=['importance']).sort_values(by='importance', ascending=False)

def scale_features(X: pd.DataFrame) -> pd.DataFrame:
    """
    Scale features
    """
    # return X
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    return pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)

# keep  it for future use
# def prepare_dataset(train: pd.DataFrame, dpi: pd.DataFrame, bnum: pd.DataFrame, features: list[str] | None = None) -> tuple[pd.DataFrame, pd.Series]:
#     """
#     Prepare dataset for training
#     """
#     dataset = prepare_data(train, dpi, bnum)
#     if features:
#         # if features are provided, we will use only them
#         X, y = dataset.drop('target', axis=1), dataset['target']
#         X_imputed = impute_dataset(X, y)
#         X_scaled = scale_features(X_imputed[features])
#         return X_scaled[features], y
#     else:
#         df_train_nulls_removed = drop_columns_with_nulls(dataset)
#         X, y = df_train_nulls_removed.drop('target', axis=1), df_train_nulls_removed['target']
#         X_imputed = impute_dataset(X, y)
#         X_scaled = scale_features(X_imputed)
#         return X_scaled, y

def prepare_dataset(train: pd.DataFrame, dpi: pd.DataFrame, bnum: pd.DataFrame, features: list[str] | None = None) -> tuple[pd.DataFrame, pd.Series]:
    """
    Prepare dataset for training
    """
    dataset = prepare_data(train, dpi, bnum)
    if features:
        # if features are provided, we will use only them
        X, y = dataset.drop('target', axis=1), dataset['target']
        X = X[features]
        X = impute_dataset(X, y)
#         X_scaled = scale_features(X_imputed[features])
#         pca = PCA(n_components=2)
#         pca_result = pca.fit_transform(scaled_data)
        return X, y
    else:
        df_train_nulls_removed = drop_columns_with_nulls(dataset)
        X, y = df_train_nulls_removed.drop('target', axis=1), df_train_nulls_removed['target']
        X = impute_dataset(X, y)
#         X_scaled = scale_features(X_imputed)
#         pca = PCA(n_components=2)
#         pca_result = pca.fit_transform(scaled_data)
        return X, y

## FEATURE SELECTION

# SK learn FEATURE selection 

from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.inspection import permutation_importance
# ligtgbm features
import lightgbm as lgb
import xgboost as xgb
from functools  import partial


# model parameters tuning
from sklearn.ensemble import RandomForestClassifier
from skopt import BayesSearchCV
from skopt.space import Real, Integer
from skopt.searchcv import BayesSearchCV


def get_low_variance_features(X: pd.DataFrame, y:  pd.Series, threshold: float = 0.8, **kwargs) -> pd.DataFrame:
    """
    Get features with low variance
    """
    sel = VarianceThreshold(threshold=(threshold * (1 - threshold)))
    sel.fit_transform(X, y)
    return X.columns[sel.get_support(indices=True)].to_list()


# using KBEST
def get_k_best_features(X: pd.DataFrame, y: pd.Series, k: int = 200, **kwargs) -> pd.DataFrame:
    """
    Get K best features
    """
    selection_method = SelectKBest(f_classif, k=k)
    selection_method.fit_transform(X, y)
    return X.columns[selection_method.get_support(indices=True)].to_list()


# select from model
def get_features_from_model(X: pd.DataFrame, y: pd.Series, **kwargs) -> list[str]:
    """
    Get features from model
    """

    model = SelectFromModel(
        estimator=ExtraTreesClassifier(n_estimators=50).fit(X, y), 
        prefit=True
    )
    model.transform(X)
    return X.columns[model.get_support(indices=True)].to_list()


def get_xgboos_features(X: pd.DataFrame, y: pd.Series, threshold: float=0.0018, **kwargs) -> list[str]:
    """
    Get features from using XGBoost
    """

    model = partial(xgb.XGBModel, objective='binary:logistic') 
    features = estimate_feature_importance(X, y, model)
    return features.abs()[features.importance>threshold].index.tolist()


def get_lgbm_features(X: pd.DataFrame, y: pd.Series, importance_type: str = 'gain', importance=3, **kwargs) -> list[str]:
    """
    Get features from using LightGBM
    """
    lgb_features = estimate_feature_importance(X, y, partial(lgb.LGBMClassifier, importance_type=importance_type))


    
    return lgb_features[lgb_features.importance > importance].index.to_list()


def get_correlation_features(X: pd.DataFrame, y: pd.Series,  threshold=0.1, **kwargs) -> list[str]:
    """
    Get features from using correlation
    """
    corr = X.corrwith(y)
    
    return corr[abs(corr) > threshold].index.to_list()


def get_rfe_features(X: pd.DataFrame, y: pd.Series, n_features_to_select=200, **kwargs) -> list[str]:
    """
    Get features from using RFE
    """
    from sklearn.feature_selection import RFE
    rfe = RFE(estimator=RandomForestClassifier(), n_features_to_select=n_features_to_select, verbose=1)
    rfe.fit(X, y)
    return X.columns[rfe.support_].to_list()

def get_features_mars_model(X: pd.DataFrame, y: pd.Series, **kwargs) -> list[str]:
    """
    Get features from using MARS model
    """
    from pyearth import Earth
    model = Earth()
    model.fit(X, y)
    # sort by importance
    

    return X.columns[model.feature_importances_ > 0.01].to_list()




def get_features_by_permutation(X: pd.DataFrame, y: pd.Series, X_val:  pd.DataFrame, y_val: pd.DataFrame) -> list[str]:
    # feature permutation
    model =  lgb.LGBMClassifier(random_state=RANDOM_STATE)

    lgbm_features  = get_lgbm_features(55)

    X_test_lgbm = X_val[lgbm_features]
    X_train_lgbm = X[lgbm_features]

    _, X_test, _, y_test = train_test_split(X_test_lgbm, y_val, test_size=0.2)

    model.fit(X_train_lgbm, y)
    r = permutation_importance(model, X_test, y_test,
                            n_repeats=30,
                            random_state=0)
    res  = {}
    for i in r.importances_mean.argsort()[::-1]:
        if r.importances_mean[i] - 2 * r.importances_std[i] > 0:
            print(f"{X_train_lgbm.columns[i]:<8}"
                f"{r.importances_mean[i]:.3f}"
                f" +/- {r.importances_std[i]:.3f}")
            res[X_train_lgbm.columns[i]]  = r.importances_mean[i]


def find_params_xgboost(X: pd.DataFrame, y: pd.DataFrame, eval_metric='auc', **kwargs) -> BayesSearchCV:
    xgb_search_space  = {
        'n_estimators': Integer(50, 1000),
        'learning_rate': Real(0.01, 0.3, prior='log-uniform'),
        'max_depth': Integer(3, 10),
        'min_child_weight': Integer(1, 10),
        'gamma': Real(0, 0.5),
        'subsample': Real(0.6, 1.0, prior='uniform'),
        'colsample_bytree': Real(0.6, 1.0, prior='uniform'),
        'reg_alpha': Real(0.01, 1.0, prior='log-uniform'),
        'reg_lambda': Real(0.01, 1.0, prior='log-uniform'),
        'scale_pos_weight': Real(1.0, 10.0, prior='uniform')
    }
    xgb_bayes_cv = BayesSearchCV(
        estimator=xgb.XGBClassifier(
            use_label_encoder=False, random_state=RANDOM_STATE,
            **kwargs,
            **(dict(eval_metric=eval_metric) if eval_metric else {})
        ),
        search_spaces=xgb_search_space,
        n_iter=32,
        cv=3,
        n_jobs=-1,
        verbose=0,
        random_state=RANDOM_STATE
    )
    xgb_bayes_cv.fit(X, y)
    return xgb_bayes_cv


def find_params_rfc(X: pd.DataFrame, y: pd.DataFrame) -> BayesSearchCV:
    rf_search_space = {
        'n_estimators': Integer(50, 200),
        'max_depth': Integer(3, 20),
        'min_samples_split': Integer(2, 20),
        'min_samples_leaf': Integer(1, 20),
        'bootstrap': [True, False]
    }
    rf_bayes_cv = BayesSearchCV(
        estimator=RandomForestClassifier(random_state=RANDOM_STATE, criterion='gini'),
        search_spaces=rf_search_space,
        n_iter=32,
        cv=3,
        n_jobs=-1,
        verbose=0,
        random_state=RANDOM_STATE
    )
    rf_bayes_cv.fit(X, y)
    return rf_bayes_cv


def find_params_lgbmc(X: pd.DataFrame, y: pd.DataFrame, metric: str|None = None, lgbmc_kwargs: dict | None = None) -> BayesSearchCV:
    lgbm_search_space  = {
        'num_leaves': Integer(31, 150),
        'learning_rate': Real(0.01, 0.2, prior='log-uniform'),
        'n_estimators': Integer(100, 1000),
        'max_depth': Integer(-1, 20),
        'min_child_samples': Integer(10, 100),
        'subsample': Real(0.6, 1.0, prior='uniform'),
        'colsample_bytree': Real(0.6, 1.0, prior='uniform'),
        'reg_alpha': Real(0.0, 1.0, prior='uniform'),
        'reg_lambda': Real(0.0, 1.0, prior='uniform')
    }
    lgbm_bayes_cv = BayesSearchCV(
        estimator=lgb.LGBMClassifier(
            objective='binary',
            random_state=RANDOM_STATE, 
            verbose=-1,
            **(dict(metric=metric) if metric else {}),
            **(lgbmc_kwargs if lgbmc_kwargs else {})
        ),
        search_spaces=lgbm_search_space,
        n_iter=32,
        cv=3,
        n_jobs=-1,
        verbose=0,
        random_state=RANDOM_STATE
    )
    lgbm_bayes_cv.fit(X, y)
    return lgbm_bayes_cv



### Features set scoring
# let's implement   a  function for validation of  model

from collections import defaultdict
from sklearn.metrics import f1_score, log_loss, precision_score, recall_score, roc_auc_score, auc
from sklearn.model_selection import cross_validate
import typing as t
from collections import Counter

from sklearn.metrics import make_scorer, precision_score, recall_score, f1_score


# Define the scoring metrics
def estimate_feature_set(model, X: pd.DataFrame, y: pd.Series, feature_set: t.Iterable | None = None ) -> dict:
    """
    Score feature set
    """
    X_features = X[list(feature_set)] if feature_set else X

    scoring = {
        'precision': make_scorer(precision_score, average='macro'),
        'recall': make_scorer(recall_score, average='macro'),
        'f1': make_scorer(f1_score, average='macro')
    }
    

    # Perform cross-validation
    scores = cross_validate(model, X_features, y, cv=5,  scoring=scoring, return_train_score=True)

    precision_scores = scores['test_precision']
    recall_scores = scores['test_recall']
    f1_scores = scores['test_f1']

    print(f'Model: {model.__class__.__name__}: Accuracy scores: {precision_scores.mean()} \tRecall scores: {recall_scores.mean()}\tF1 scores: {f1_scores.mean()}')
    return scores

def score_feature_set(model, X: pd.DataFrame, y: pd.Series, feature_set: t.Iterable | None = None ) -> dict:
    """
    Score feature set
    """
    X_features = X[list(feature_set)] if feature_set else X

    scoring = {
        'precision': make_scorer(precision_score, average='macro'),
        'recall': make_scorer(recall_score, average='macro'),
        'f1': make_scorer(f1_score, average='macro')
    }
    

    # Perform cross-validation
    scores = cross_validate(model, X_features, y, cv=5,  scoring=scoring, return_train_score=True)

    precision_scores = scores['test_precision']
    recall_scores = scores['test_recall']
    f1_scores = scores['test_f1']

    print(f'Model: {model.__class__.__name__}: Accuracy scores: {precision_scores.mean()} \tRecall scores: {recall_scores.mean()}\tF1 scores: {f1_scores.mean()}')
    return scores


def select_best_feature_set(
        X: pd.DataFrame,
        y: pd.Series,
        estimators: list, 
        feature_sets: dict, 
        column_limit: int = 274, 
        default_set: str | None = None,
    ) -> None:

    always_include = feature_sets[default_set] if default_set else set()

    model_max = {}
    SCORES = defaultdict(dict)
    
    for model in estimators:
        for ds_name, columns in feature_sets.items():
            columns_ = columns[:column_limit] if len(columns) > column_limit else columns
            print(f'Dataset: {ds_name}', end='\t')
            SCORES[model][ds_name] = score_feature_set(model,  X, y.astype(int), set(columns_).union(always_include))


    ds_counter = Counter()
    for model, metrics in SCORES.items():
        model_name = model.__class__.__name__
        print(f'For Model: {model_name}  winner is:  ', end='\t')
        # ds scorring
        score_to_dict = {tuple([v.mean() for k,v in scores.items() if k in {'test_precision','test_recall','test_f1'}]): ds for ds, scores in metrics.items()}
        max_mean = max(score_to_dict.keys())
        print(f'{score_to_dict[max_mean]} with score: {max_mean}')
        ds_counter[score_to_dict[max_mean]] += 1
        model_max[model_name] = max_mean
    print(f'Dataset Winner is: {ds_counter.most_common()[0]}\nModel winner is: {max(model_max, key=model_max.get)}')


## MODEL ESTIMATION

# MAke predictions
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import seaborn as sns
import matplotlib.pyplot as plt


def evaluate_model(model, X: pd.DataFrame, y: pd.Series, threshold: float = 0.5) -> None:
    """
    Evaluate model
    """
    # preds = model.predict(X)
    preds = model.predict_proba(X)[:, 1]

    # Use the default threshold (0.5)

    preds = (preds >= threshold).astype(int)
    print(f'Accuracy: {accuracy_score(y, preds)}')
    print(f'F1: {f1_score(y, preds)}')
    print(f'Precision: {precision_score(y, preds)}')
    print(f'Recall: {recall_score(y, preds)}')
    print(f'ROC AUC: {roc_auc_score(y, preds)}')

    auc_score = roc_auc_score(y, model.predict_proba(X)[:,1])
    cm = confusion_matrix(y, preds, labels=model.classes_)
    print(f'AUC: {auc_score}')
    print(f'Classification Report: {classification_report(y, preds, target_names=["not churn", "churn"])}')
    print(f'ROC Curve: {roc_curve(y, preds)}')
    # plot confusion matrix

    
    # Plot confusion matrix

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot()
    plt.show()

    # ConfusionMatrixDisplay(confusion_matrix(y, preds)).plot()


def cap_outliers_to_normal_bounds(df):
    """
    Transform outliers in the DataFrame to be within the boundaries of a normal distribution.
    
    Parameters:
    df (pd.DataFrame): The input DataFrame with numerical features.
    
    Returns:
    pd.DataFrame: A DataFrame with outliers capped within normal boundaries.
    """
    df_capped = df.copy()
    
    for column in df_capped.select_dtypes(include=[np.number]).columns:
        Q1 = df_capped[column].quantile(0.25)
        Q3 = df_capped[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        # Cap the outliers
        df_capped[column] = np.where(df_capped[column] < lower_bound, lower_bound, df_capped[column])
        df_capped[column] = np.where(df_capped[column] > upper_bound, upper_bound, df_capped[column])
    
    return df_capped

def get_continuous(df, variance_threshold=25) -> list[str]:
    cals_continuous = df.columns[df.nunique() > variance_threshold]
    return cals_continuous.to_list()

def _get_feature_with_high_singular_value_content(df: pd.DataFrame, threshold: float = 0.9, plot: bool = False) -> pd.Series:
    most_frequent_entry =  df.drop(columns=['abon_id']).mode()
    df_freq  = df.eq(most_frequent_entry.iloc[0], axis=1)
    df_freq_ = df_freq.mean()
    with_threshold = df_freq_[df_freq_ > threshold]
    if plot:
        with_threshold.sort_values(ascending=False).head(100).plot(kind='bar', figsize=(20, 4))
        plt.title('Top Features with Highest Ratio of Singular Value Content')
        plt.ylabel('Frequency Ratio')
        plt.xlabel('Features')
        plt.show()
    return with_threshold.index.to_list()

def get_high_variance(df, ratio=0.9) -> list[str]:
    high_single_ratio = _get_feature_with_high_singular_value_content(df, ratio)
    return list(set(df.columns) - set(high_single_ratio))

def get_skewed(df) -> list[str]:
    # Calculate skewness for each feature
    skewness = df.skew()
    return skewness[(skewness > 1) | (skewness < -1)].index.to_list()


def scale_features(X: pd.DataFrame) -> pd.DataFrame:
    """
    Scale features
    """
    # return X
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    return pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)

def get_one_hot(df):
    maxes = df.max()
    return  maxes[(maxes <= 1) & (maxes >= 0)].index.to_list()
    
    

def prepare_features(df):
    """
    Only column manipulations (no  rows affected)
    """
    hv_features = get_high_variance(df)
    # apply capp
    df_cap = cap_outliers_to_normal_bounds(df[hv_features])
    continuous_features = get_continuous(df_cap)
    
    skewed_features = get_skewed(df_cap[continuous_features])
    normal_features = list(set(continuous_features) - set(skewed_features))
    non_continuous_features = list(set(hv_features) - set(continuous_features))

    one_hot_fetures = get_one_hot(df_cap[non_continuous_features])
    ordinal_features =  list(set(non_continuous_features) - set(one_hot_fetures))
    
    # apply log1p for skewed
    skewed = df_cap[skewed_features].apply(np.log1p)
    # apply scaler for normal
    normal = scale_features(df_cap[normal_features])
    ordinal = scale_features(df_cap[ordinal_features])
    one_hot = df_cap[one_hot_fetures]
    return pd.concat([skewed, normal, ordinal, one_hot], axis=1)

# %%
with open(r'Data/churn_model_pd2.pcl', 'rb') as f:
    bdl_data = pickle.load(f)
gen_info, train_data, test_data = bdl_data
train_info, df_train_fe, df_train_bnum, df_train_dpi = train_data
test_info, df_test_fe, df_test_bnum, df_test_dpi = test_data

# %%
# df_train = prepare_data(df_train_fe, df_train_dpi, df_train_bnum)

X_train, y_train = prepare_dataset(df_train_fe, df_train_dpi, df_train_bnum)

# df_train_nulls_removed = drop_columns_with_nulls(df_train)
# print(f'before: {df_train.shape}, after: {df_train_nulls_removed.shape}')

# X_train, y_train = df_train_nulls_removed.drop('target', axis=1), df_train_nulls_removed['target']

# %%
X_train.shape, y_train.shape
# Out:
# ((150000, 870), (150000,))

# %%
df_train_fe.describe()
# Out:
#        Ama_rchrgmnt_sum_max_mnt1  content_clc_mea_mnt1  content_cnt_max_mnt1  \
# count                   150000.0         150000.000000         150000.000000
# mean                         0.0              0.033657             11.493424
# std                          0.0              0.396473              3.470090
# min                          0.0              0.000000              0.000000
# 25%                          0.0              0.000000              9.669721
# 50%                          0.0              0.000000             11.615193
# 75%                          0.0              0.000000             13.640500
# max                          0.0             22.842175             64.086762
#
#        voice_out_short_part_max_mnt1  voice_mts_in_nrest_part_std_mnt1  \
# count                  150000.000000                     150000.000000
# mean                        0.617709                          0.624438
# std                         0.500780                          0.491706
# min                         0.000000                          0.000000
# 25%                         0.000000                          0.000000
# 50%                         1.001149                          1.000230
# 75%                         1.005923                          1.003669
# max                         1.480453                          1.207705
#
#        num_act_days_max_mnt1  sms_roam_clc_min_mnt1  \
# count          150000.000000               150000.0
# mean                5.135702                    0.0
# std                 0.678199                    0.0
# min                 0.000000                    0.0
# 25%                 5.324077                    0.0
# 50%                 5.324077                    0.0
# 75%                 5.324077                    0.0
# max                 5.324077                    0.0
#
#        voice_in_cmpttrs_avg_durmin_mnt1  com_num_part_mea_mnt1  \
# count                     150000.000000          150000.000000
# mean                           6.422773               0.938628
# std                            9.102909               0.413042
# min                            0.000000               0.000000
# 25%                            0.000000               1.004508
# 50%                            0.000000               1.038586
# 75%                           13.775024               1.132903
# max                           52.754028               2.206949
#
#        pay_avg_mea_mnt1  ...  MV_Traf_mn_out_v_Min      MV_DOU_OT  \
# count     150000.000000  ...         148287.000000  108550.000000
# mean           9.062899  ...              0.252807       1.849057
# std            7.441644  ...              1.721168       0.664153
# min          -29.768600  ...              0.000000       1.480453
# 25%            0.000000  ...              0.000000       1.480453
# 50%           11.615193  ...              0.000000       1.480453
# 75%           14.327306  ...              0.000000       2.206949
# max           51.861124  ...             72.104227      13.011325
#
#        MV_SERV_Y_WO_AF     MV_Migr_To  MV_SERV_RLH  MV_DOU_PPM_VF  \
# count           9030.0  149909.000000         33.0   77634.000000
# mean               1.0       0.029378          1.0      15.495140
# std                0.0       0.168864          0.0       2.850583
# min                1.0       0.000000          1.0       1.480453
# 25%                1.0       0.000000          1.0      13.011325
# 50%                1.0       0.000000          1.0      16.459253
# 75%                1.0       0.000000          1.0      18.165565
# max                1.0       1.000000          1.0      18.165565
#
#        MV_DOU_Neg_Bal    MV_ot_total         target       abon_id
# count      113.000000  108550.000000  150000.000000  1.500000e+05
# mean         2.971758       6.290761       0.063907  7.897443e+07
# std          1.699820      10.612428       0.244587  4.293146e+07
# min          1.480453       0.000000       0.000000  1.545052e+06
# 25%          1.480453       0.000000       0.000000  3.700322e+07
# 50%          2.206949       0.000000       0.000000  8.837582e+07
# 75%          4.210402      17.739542       0.000000  1.234651e+08
# max         13.011325      61.534136       1.000000  1.307549e+08
#
# [8 rows x 817 columns]

# %%
X_train.describe()
# Out:
#        Ama_rchrgmnt_sum_max_mnt1  content_clc_mea_mnt1  content_cnt_max_mnt1  \
# count                   150000.0          1.500000e+05          1.500000e+05
# mean                         0.0         -5.684342e-19          2.944489e-16
# std                          0.0          1.000003e+00          1.000003e+00
# min                          0.0         -8.489240e-02         -3.312151e+00
# 25%                          0.0         -8.489240e-02         -5.255510e-01
# 50%                          0.0         -8.489240e-02          3.509115e-02
# 75%                          0.0         -8.489240e-02          6.187398e-01
# max                          0.0          5.752875e+01          1.515624e+01
#
#        voice_out_short_part_max_mnt1  voice_mts_in_nrest_part_std_mnt1  \
# count                   1.500000e+05                      1.500000e+05
# mean                   -4.850638e-17                     -1.121710e-16
# std                     1.000003e+00                      1.000003e+00
# min                    -1.233497e+00                     -1.269947e+00
# 25%                    -1.233497e+00                     -1.269947e+00
# 50%                     7.656888e-01                      7.642649e-01
# 75%                     7.752213e-01                      7.712587e-01
# max                     1.722806e+00                      1.186215e+00
#
#        num_act_days_max_mnt1  sms_roam_clc_min_mnt1  \
# count           1.500000e+05               150000.0
# mean           -2.331125e-15                    0.0
# std             1.000003e+00                    0.0
# min            -7.572585e+00                    0.0
# 25%             2.777585e-01                    0.0
# 50%             2.777585e-01                    0.0
# 75%             2.777585e-01                    0.0
# max             2.777585e-01                    0.0
#
#        voice_in_cmpttrs_avg_durmin_mnt1  com_num_part_mea_mnt1  \
# count                      1.500000e+05           1.500000e+05
# mean                      -4.964325e-17           5.854872e-17
# std                        1.000003e+00           1.000003e+00
# min                       -7.055761e-01          -2.272486e+00
# 25%                       -7.055761e-01           1.594984e-01
# 50%                       -7.055761e-01           2.420046e-01
# 75%                        8.076842e-01           4.703520e-01
# max                        5.089737e+00           3.070694e+00
#
#        pay_avg_mea_mnt1  ...  missingindicator_MV_dou_2G_d  \
# count      1.500000e+05  ...                  1.500000e+05
# mean      -4.462208e-17  ...                  3.050597e-17
# std        1.000003e+00  ...                  1.000003e+00
# min       -5.218152e+00  ...                 -1.074799e-01
# 25%       -1.217866e+00  ...                 -1.074799e-01
# 50%        3.429757e-01  ...                 -1.074799e-01
# 75%        7.074276e-01  ...                 -1.074799e-01
# max        5.751198e+00  ...                  9.304068e+00
#
#        missingindicator_MV_Traf_pstn_inc_v_Min  \
# count                             1.500000e+05
# mean                              3.050597e-17
# std                               1.000003e+00
# min                              -1.074799e-01
# 25%                              -1.074799e-01
# 50%                              -1.074799e-01
# 75%                              -1.074799e-01
# max                               9.304068e+00
#
#        missingindicator_MV_ARPU_R_inc_v_Traf  \
# count                           1.500000e+05
# mean                            3.050597e-17
# std                             1.000003e+00
# min                            -1.074799e-01
# 25%                            -1.074799e-01
# 50%                            -1.074799e-01
# 75%                            -1.074799e-01
# max                             9.304068e+00
#
#        missingindicator_MV_ARPU_2G_d_Traf  missingindicator_MV_ot_Other  \
# count                        1.500000e+05                  1.500000e+05
# mean                         3.050597e-17                  1.818989e-17
# std                          1.000003e+00                  1.000003e+00
# min                         -1.074799e-01                 -6.179415e-01
# 25%                         -1.074799e-01                 -6.179415e-01
# 50%                         -1.074799e-01                 -6.179415e-01
# 75%                         -1.074799e-01                  1.618276e+00
# max                          9.304068e+00                  1.618276e+00
#
#        missingindicator_MV_Traf_ACCA_out_v_Min  \
# count                             1.500000e+05
# mean                              3.050597e-17
# std                               1.000003e+00
# min                              -1.074799e-01
# 25%                              -1.074799e-01
# 50%                              -1.074799e-01
# 75%                              -1.074799e-01
# max                               9.304068e+00
#
#        missingindicator_MV_Traf_mn_out_v_Min  missingindicator_MV_DOU_OT  \
# count                           1.500000e+05                1.500000e+05
# mean                            3.050597e-17                1.818989e-17
# std                             1.000003e+00                1.000003e+00
# min                            -1.074799e-01               -6.179415e-01
# 25%                            -1.074799e-01               -6.179415e-01
# 50%                            -1.074799e-01               -6.179415e-01
# 75%                            -1.074799e-01                1.618276e+00
# max                             9.304068e+00                1.618276e+00
#
#        missingindicator_MV_Migr_To  missingindicator_MV_ot_total
# count                 1.500000e+05                  1.500000e+05
# mean                 -1.364242e-17                  1.818989e-17
# std                   1.000003e+00                  1.000003e+00
# min                  -2.463808e-02                 -6.179415e-01
# 25%                  -2.463808e-02                 -6.179415e-01
# 50%                  -2.463808e-02                 -6.179415e-01
# 75%                  -2.463808e-02                  1.618276e+00
# max                   4.058758e+01                  1.618276e+00
#
# [8 rows x 870 columns]

# %%
y_train.value_counts()

# %%
X_train.shape, y_train.shape

# %% [markdown]
# ## 2. Data Pre-processing EDA

# %% [markdown]
# ### 2.2 Balance a dataset with undersampling

# %%
# let's balance dataset
# using undersampling
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=RANDOM_STATE)
X_train_under_, y_train_under_ = rus.fit_resample(X_train, y_train)

# and we're ready to search feature importance/corelations
# to reduce size of train data for experiment

X_train_under, X_test_under, y_train_under, y_test_under = train_test_split(
  X_train_under_, y_train_under_, test_size=0.2,  shuffle=True, random_state=RANDOM_STATE, stratify=y_train_under_
)

# %%
# stratified split


X_train_, X_test_, y_train_, y_test_ = train_test_split(
  X_train, y_train, test_size=0.7,  shuffle=True, random_state=RANDOM_STATE, stratify=y_train
)

X_train_stratified, X_val_stratified, y_train_stratified, y_val_stratified = train_test_split(
  X_train_, y_train_, test_size=0.2,  shuffle=True, random_state=RANDOM_STATE, stratify=y_train_
)

# %%
X_train_stratified.shape, X_val_stratified.shape, y_train_stratified.shape, y_val_stratified.shape
# Out:
# ((36000, 870), (9000, 870), (36000,), (9000,))

# %%
# handle  imbalanced dataset
# using oversampling
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=RANDOM_STATE)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

# %%
X_train_over.shape, y_train_over.shape

# %% [markdown]
# ## 3. Feature Selection

# %% [markdown]
# ### 3.1  Select  features  using various techniques

# %%
y_train_stratified.value_counts()
# Out:
# target
# 0.0    42124
# 1.0     2876
# Name: count, dtype: int64

# %%
# select features for oversampled dataset
selected_features_over  = {}

# %%
# print length of selected features
for method_name, method in selected_features_over.items():
    print(f'{method_name}: {len(method)}')
# Out:
# low_variance_features: 826
# k_best_features: 200
# features_from_model: 372
# xgboost_features: 69
# lgbm_features: 526
# correlation: 417

# %%
for (method_name, method) in [
        ('low_variance_features', get_low_variance_features),   
        ('k_best_features', get_k_best_features),
        ('features_from_model', get_features_from_model),
        ('xgboost_features', get_xgboos_features),
        ('lgbm_features', get_lgbm_features),
        ('correlation', get_correlation_features),
        # ('rfe', get_rfe_features),
        # ('features_by_permutation', get_features_by_permutation) # this method is heavy
    ]:
    selected_features_over[method_name] = method(X_train_stratified, y_train_stratified, X_val=X_val_stratified, y_val=y_val_stratified)
# Out:
# /Users/andriigerasymchuk/private-repositories/ml-projects/venv/lib/python3.11/site-packages/sklearn/feature_selection/_univariate_selection.py:112: UserWarning: Features [  0   6  25  62  63  83 105 121 128 140 166 174 200 218 222 267 270 286
#  304 344 370 392 400 446 460 484 490 502 515 545 561 593 607 663 673 677
#  687 692 706 709] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# /Users/andriigerasymchuk/private-repositories/ml-projects/venv/lib/python3.11/site-packages/sklearn/feature_selection/_univariate_selection.py:113: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw
# /Users/andriigerasymchuk/private-repositories/ml-projects/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 2301, number of negative: 33699
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.608440 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 129032
# [LightGBM] [Info] Number of data points in the train set: 36000, number of used features: 799
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063917 -> initscore=-2.684124
# [LightGBM] [Info] Start training from score -2.684124
# /Users/andriigerasymchuk/private-repositories/ml-projects/venv/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/andriigerasymchuk/private-repositories/ml-projects/venv/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
# print len of each record in selected_features_over
for k, v in selected_features_over.items():
    print(f'{k}: {len(v)}')
# Out:
# low_variance_features: 826
# k_best_features: 200
# features_from_model: 372
# xgboost_features: 69
# lgbm_features: 526
# correlation: 417

# %% [markdown]
# ### 3.2 Estimate quality of selected features (scorring)

# %%
selected_features_over
# Out:
# {'low_variance_features': ['content_clc_mea_mnt1',
#   'content_cnt_max_mnt1',
#   'voice_out_short_part_max_mnt1',
#   'voice_mts_in_nrest_part_std_mnt1',
#   'num_act_days_max_mnt1',
#   'voice_in_cmpttrs_avg_durmin_mnt1',
#   'com_num_part_mea_mnt1',
#   'pay_avg_mea_mnt1',
#   'voice_out_tar_dur_std_mnt1',
#   'voice_out_tar_dur_min_mnt1',
#   'gprs_clc_mea_mnt1',
#   'pay_max_min_mnt3',
#   'voice_in_short_part_mea_mnt3',
#   'voice_in_roam_clc_std_mnt1',
#   'conn_out_uniq_cnt_std_mnt1',
#   'voice_mts_in_dwork_part_td_mnt3',
#   'data_3g_tar_vol_mea_mnt3',
#   'voice_in_fix_tar_dur_mea_mnt3',
#   'voice_in_tar_dur_max_mnt3',
#   'ks_num_part_td_mnt3',
#   'data_3g_dou_mea_mnt3',
#   'voice_mts_out_drest_partmea_mnt1',
#   'conn_com_part_min_mnt1',
#   'voice_mts_in_dwork_part_mea_wk1',
#   'voice_mts_in_dwork_part_std_mnt1',
#   'gprs_clc_std_mnt1',
#   'conn_com_part_td_mnt3',
#   'sms_clc_min_mnt3',
#   'gprs_clc_mea_mnt3',
#   'voice_in_cmpttrs_avg_durmax_mnt3',
#   'voice_in_tar_dur_td_mnt3',
#   'conn_in_uniq_cnt_td_mnt3',
#   'voice_mts_out_nrest_partmax_mnt1',
#   'voice_in_tar_dur_std_mnt1',
#   'voice_mts_out_dwork_partmea_wk1',
#   'voice_out_fix_tar_dur_td_mnt3',
#   'all_clc_mea_mnt1',
#   'voice_out_cmpttrs_td_cnttd_mnt3',
#   'all_roam_clc_mea_mnt1',
#   'voice_in_tar_dur_std_mnt3',
#   'voice_in_td_cnt_max_mnt3',
#   'voice_out_fix_tar_dur_mea_wk1',
#   'conn_com_part_std_mnt3',
#   'voice_in_roam_clc_mea_mnt3',
#   'pay_p2p_in_sum_max_mnt3',
#   'content_cnt_mea_mnt1',
#   'voice_in_roam_clc_mea_wk1',
#   'com_num_part_min_mnt1',
#   'pay_p2p_in_sum_mea_wk1',
#   'all_home_clc_td_mnt3',
#   'voice_out_td_cnt_mea_mnt1',
#   'vas_clc_mea_wk1',
#   'com_num_part_max_mnt1',
#   'voice_mts_out_drest_partstd_mnt3',
#   'pay_sum_td_mnt3',
#   'pay_p2p_in_sum_std_mnt1',
#   'conn_out_uniq_cnt_std_mnt3',
#   'all_clc_min_mnt3',
#   'voice_in_cmpttrs_td_cnt_max_mnt1',
#   'voice_mts_out_nrest_partstd_mnt3',
#   'voice_in_td_cnt_mea_mnt3',
#   'data_3g_dou_min_mnt3',
#   'voice_mts_in_nrest_part_mea_wk1',
#   'voice_in_fix_tar_dur_max_mnt1',
#   'ks_num_part_mea_wk1',
#   'pay_p2p_out_sum_std_mnt1',
#   'block_all_dur_min_mnt1',
#   'voice_in_cmpttrs_td_cnt_max_mnt3',
#   'pay_sum_std_mnt1',
#   'abon_part_max_mnt3',
#   'sms_out_cnt_std_mnt3',
#   'sms_in_cnt_min_mnt1',
#   'conn_in_uniq_cnt_mea_wk1',
#   'pay_sum_min_mnt3',
#   'ama_volume_max_mnt3',
#   'vas_clc_min_mnt3',
#   'voice_in_td_cnt_std_mnt1',
#   'all_cnt_min_mnt1',
#   'voice_in_short_part_max_mnt1',
#   'accum_mts_dur_std_mnt3',
#   'data_3g_tv_cnt_mea_wk1',
#   'voice_out_td_cnt_min_mnt1',
#   'data_3g_tar_vol_mea_mnt1',
#   'voice_mts_out_nrest_partmin_mnt1',
#   'all_cnt_mea_mnt1',
#   'data_3g_dou_std_mnt3',
#   'voice_in_short_part_min_mnt3',
#   'sms_in_cnt_td_mnt3',
#   'voice_mts_out_dwork_partstd_mnt1',
#   'voice_out_short_part_mea_wk1',
#   'voice_in_fix_tar_dur_mea_wk1',
#   'block_all_dur_min_mnt3',
#   'pay_sum_max_mnt1',
#   'content_cnt_mea_wk1',
#   'voice_mts_out_nwork_partstd_mnt1',
#   'com_num_part_mea_mnt3',
#   'conn_out_uniq_cnt_max_mnt3',
#   'content_clc_mea_mnt3',
#   'conn_out_uniq_cnt_mea_mnt3',
#   'gprs_clc_std_mnt3',
#   'voice_out_short_part_min_mnt1',
#   'all_cnt_std_mnt1',
#   'conn_com_part_mea_wk1',
#   'com_num_part_max_mnt3',
#   'voice_out_fix_tar_dur_max_mnt1',
#   'pay_p2p_out_sum_mea_mnt1',
#   'abon_part_min_mnt1',
#   'accum_mts_dur_min_mnt1',
#   'content_clc_min_mnt1',
#   'voice_out_fix_tar_dur_std_mnt1',
#   'voice_mts_out_nwork_partmin_mnt1',
#   'vas_clc_max_mnt3',
#   'pay_avg_std_mnt1',
#   'pay_p2p_out_sum_mea_mnt3',
#   'data_3g_tar_vol_std_mnt1',
#   'vas_clc_min_mnt1',
#   'sms_in_cnt_mea_mnt1',
#   'com_num_part_td_mnt3',
#   'all_home_clc_mea_mnt3',
#   'voice_in_short_part_max_mnt3',
#   'pay_max_max_mnt1',
#   'sms_clc_std_mnt1',
#   'pay_max_mea_mnt1',
#   'accum_mts_dur_td_mnt3',
#   'gprs_clc_max_mnt3',
#   'vas_clc_mea_mnt1',
#   'all_clc_mea_mnt3',
#   'voice_in_kievstar_part_min_mnt1',
#   'sms_in_cnt_min_mnt3',
#   'voice_mts_in_drest_part_td_mnt3',
#   'voice_mts_in_dwork_part_min_mnt1',
#   'voice_in_cmpttrs_td_cnt_mea_mnt1',
#   'sms_roam_clc_max_mnt3',
#   'pay_max_mea_mnt3',
#   'gprs_clc_td_mnt3',
#   'ks_num_part_std_mnt1',
#   'voice_in_mts_avg_dur_max_mnt1',
#   'voice_in_td_cnt_mea_mnt1',
#   'voice_mts_in_drest_part_max_mnt3',
#   'accum_mts_dur_max_mnt3',
#   'pay_p2p_out_sum_max_mnt1',
#   'sms_roam_clc_std_mnt3',
#   'voice_out_cmpttrs_td_cntmin_mnt3',
#   'voice_out_cmpttrs_avg_dumax_mnt1',
#   'voice_mts_in_nrest_part_mea_mnt3',
#   'voice_out_tar_dur_max_mnt1',
#   'voice_mts_in_drest_part_std_mnt1',
#   'clc_no_vas_roam_std_mnt3',
#   'non_accum_internet_vol_mea_wk1',
#   'voice_mts_out_nwork_partmea_mnt1',
#   'voice_mts_in_nrest_part_min_mnt1',
#   'data_3g_dou_td_mnt3',
#   'voice_out_cmpttrs_avg_dustd_mnt3',
#   'ama_volume_min_mnt1',
#   'ama_volume_td_mnt3',
#   'voice_in_td_cnt_max_mnt1',
#   'sms_clc_std_mnt3',
#   'voice_in_kievstar_part_std_mnt3',
#   'gprs_tar_vol_td_mnt3',
#   'accum_mts_dur_mea_mnt3',
#   'voice_in_fix_tar_dur_mea_mnt1',
#   'conn_in_uniq_cnt_max_mnt1',
#   'pay_sum_std_mnt3',
#   'pay_max_mea_wk1',
#   'vas_clc_td_mnt3',
#   'all_home_clc_mea_mnt1',
#   'voice_in_cmpttrs_td_cnt_std_mnt1',
#   'accum_oth_dur_min_mnt3',
#   'sms_in_cnt_mea_mnt3',
#   'voice_out_short_part_mea_mnt3',
#   'data_3g_tar_vol_std_mnt3',
#   'sms_out_cnt_mea_mnt1',
#   'voice_out_short_part_td_mnt3',
#   'pay_p2p_out_sum_std_mnt3',
#   'content_cnt_td_mnt3',
#   'gprs_tar_vol_mea_wk1',
#   'com_num_part_min_mnt3',
#   'conn_out_uniq_cnt_mea_mnt1',
#   'pay_p2p_in_sum_std_mnt3',
#   'voice_mts_in_nwork_part_td_mnt3',
#   'vas_clc_max_mnt1',
#   'voice_in_cmpttrs_avg_durmea_mnt1',
#   'voice_mts_out_nrest_partmea_mnt3',
#   'non_accum_internet_vol_min_mnt1',
#   'pay_sum_mea_mnt3',
#   'content_cnt_std_mnt1',
#   'voice_out_cmpttrs_td_cntmea_mnt1',
#   'voice_in_cmpttrs_avg_durmin_mnt3',
#   'conn_in_uniq_cnt_min_mnt1',
#   'voice_in_tar_dur_mea_mnt3',
#   'conn_out_uniq_cnt_mea_wk1',
#   'voice_out_td_cnt_max_mnt1',
#   'voice_in_fix_tar_dur_std_mnt3',
#   'voice_out_fix_tar_dur_mea_mnt1',
#   'all_roam_clc_std_mnt1',
#   'data_3g_tv_cnt_std_mnt3',
#   'voice_mts_out_drest_partmin_mnt1',
#   'voice_mts_out_dwork_partmea_mnt3',
#   'voice_out_fix_tar_dur_min_mnt1',
#   'pay_p2p_in_sum_mea_mnt1',
#   'non_accum_internet_vol_std_mnt1',
#   'voice_out_tar_dur_max_mnt3',
#   'sms_out_cnt_min_mnt1',
#   'voice_in_life_part_mea_mnt1',
#   'clc_no_vas_roam_mea_mnt1',
#   'sms_roam_clc_td_mnt3',
#   'voice_in_cmpttrs_avg_durmea_wk1',
#   'voice_out_cmpttrs_td_cntmea_wk1',
#   'voice_mts_out_dwork_parttd_mnt3',
#   'voice_out_fix_tar_dur_max_mnt3',
#   'voice_in_kievstar_part_td_mnt3',
#   'voice_mts_in_drest_part_mea_wk1',
#   'data_3g_dou_mea_wk1',
#   'all_cnt_mea_mnt3',
#   'voice_out_short_part_std_mnt3',
#   'voice_out_tar_dur_mea_wk1',
#   'voice_mts_out_nrest_parttd_mnt3',
#   'voice_mts_in_dwork_part_mea_mnt1',
#   'voice_in_kievstar_part_max_mnt3',
#   'clc_no_vas_roam_max_mnt3',
#   'data_3g_tar_vol_min_mnt3',
#   'data_3g_dou_max_mnt1',
#   'gprs_clc_mea_wk1',
#   'gprs_tar_vol_min_mnt1',
#   'clc_no_vas_roam_mea_mnt3',
#   'data_3g_dou_max_mnt3',
#   'voice_mts_in_nrest_part_max_mnt3',
#   'voice_in_kievstar_part_std_mnt1',
#   'voice_in_mts_avg_dur_min_mnt1',
#   'data_3g_tv_cnt_std_mnt1',
#   'all_home_clc_min_mnt3',
#   'all_clc_mea_wk1',
#   'all_clc_max_mnt1',
#   'voice_in_roam_clc_mea_mnt1',
#   'conn_in_uniq_cnt_max_mnt3',
#   'voice_out_cmpttrs_avg_dustd_mnt1',
#   'gprs_clc_max_mnt1',
#   'all_cnt_td_mnt3',
#   'conn_out_uniq_cnt_td_mnt3',
#   'all_clc_min_mnt1',
#   'all_roam_clc_mea_mnt3',
#   'voice_in_tar_dur_mea_mnt1',
#   'voice_mts_in_nwork_part_min_mnt1',
#   'sms_out_cnt_mea_wk1',
#   'pay_avg_min_mnt3',
#   'all_roam_clc_mea_wk1',
#   'clc_no_vas_roam_min_mnt1',
#   'conn_out_uniq_cnt_min_mnt1',
#   'ks_num_part_min_mnt3',
#   'content_clc_td_mnt3',
#   'voice_in_cmpttrs_td_cnt_std_mnt3',
#   'voice_mts_out_nwork_partmax_mnt3',
#   'ks_num_part_mea_mnt1',
#   'voice_mts_in_nrest_part_mea_mnt1',
#   'voice_out_short_part_max_mnt3',
#   'voice_mts_in_nrest_part_td_mnt3',
#   'voice_out_cmpttrs_td_cntstd_mnt1',
#   'accum_oth_dur_mea_mnt3',
#   'voice_mts_out_dwork_partmin_mnt1',
#   'conn_in_uniq_cnt_min_mnt3',
#   'data_3g_tv_cnt_max_mnt1',
#   'voice_in_fix_tar_dur_td_mnt3',
#   'num_act_days_std_mnt3',
#   'pay_p2p_in_sum_mea_mnt3',
#   'pay_p2p_in_sum_max_mnt1',
#   'voice_mts_in_nwork_part_max_mnt1',
#   'num_act_days_td_mnt3',
#   'ks_num_part_min_mnt1',
#   'all_home_clc_min_mnt1',
#   'block_all_dur_std_mnt1',
#   'voice_out_td_cnt_mea_wk1',
#   'ama_volume_std_mnt1',
#   'voice_in_roam_clc_std_mnt3',
#   'all_clc_td_mnt3',
#   'num_act_days_mea_wk1',
#   'data_3g_tar_vol_td_mnt3',
#   'data_3g_dou_min_mnt1',
#   'clc_no_vas_roam_std_mnt1',
#   'all_home_clc_max_mnt1',
#   'voice_in_fix_tar_dur_std_mnt1',
#   'voice_in_cmpttrs_avg_durstd_mnt1',
#   'voice_out_td_cnt_mea_mnt3',
#   'voice_in_cmpttrs_td_cnt_td_mnt3',
#   'abon_part_mea_wk1',
#   'clc_no_vas_roam_td_mnt3',
#   'conn_in_uniq_cnt_std_mnt3',
#   'non_accum_internet_vol_max_mnt1',
#   'conn_out_uniq_cnt_min_mnt3',
#   'gprs_clc_min_mnt1',
#   'voice_mts_in_drest_part_mea_mnt1',
#   'sms_out_cnt_max_mnt1',
#   'voice_in_fix_tar_dur_min_mnt3',
#   'pay_sum_min_mnt1',
#   'abon_part_std_mnt3',
#   'all_home_clc_std_mnt3',
#   'content_cnt_mea_mnt3',
#   'all_home_clc_mea_wk1',
#   'voice_mts_out_nrest_partmax_mnt3',
#   'sms_out_cnt_td_mnt3',
#   'ama_volume_mea_mnt3',
#   'voice_in_mts_avg_dur_mea_mnt3',
#   'pay_p2p_out_sum_min_mnt1',
#   'voice_out_tar_dur_td_mnt3',
#   'voice_mts_out_nwork_partmax_mnt1',
#   'voice_out_cmpttrs_avg_dumea_mnt3',
#   'voice_mts_out_drest_partmax_mnt3',
#   'voice_in_short_part_min_mnt1',
#   'voice_mts_out_drest_partmea_mnt3',
#   'voice_mts_in_drest_part_min_mnt3',
#   'sms_out_cnt_mea_mnt3',
#   'voice_mts_out_dwork_partmax_mnt3',
#   'ks_num_part_std_mnt3',
#   'pay_avg_max_mnt3',
#   'sms_clc_max_mnt3',
#   'sms_clc_td_mnt3',
#   'voice_mts_out_drest_partmax_mnt1',
#   'num_act_days_std_mnt1',
#   'all_cnt_min_mnt3',
#   'voice_in_mts_avg_dur_std_mnt1',
#   'all_roam_clc_max_mnt3',
#   'voice_out_td_cnt_td_mnt3',
#   'sms_clc_mea_wk1',
#   'voice_in_cmpttrs_td_cnt_min_mnt1',
#   'clc_no_vas_roam_mea_wk1',
#   'voice_mts_out_drest_partmea_wk1',
#   'voice_in_cmpttrs_td_cnt_mea_mnt3',
#   'voice_out_cmpttrs_avg_dumea_wk1',
#   'accum_oth_dur_max_mnt3',
#   'sms_roam_clc_mea_mnt3',
#   'gprs_tar_vol_std_mnt3',
#   'voice_out_tar_dur_min_mnt3',
#   'all_roam_clc_std_mnt3',
#   'voice_in_tar_dur_min_mnt1',
#   'pay_avg_td_mnt3',
#   'voice_mts_out_dwork_partmax_mnt1',
#   'accum_oth_dur_mea_mnt1',
#   'ama_volume_mea_mnt1',
#   'voice_mts_out_dwork_partstd_mnt3',
#   'voice_mts_in_drest_part_min_mnt1',
#   'voice_mts_out_drest_partstd_mnt1',
#   'voice_mts_out_nwork_partmin_mnt3',
#   'voice_out_short_part_min_mnt3',
#   'accum_mts_dur_min_mnt3',
#   'conn_com_part_min_mnt3',
#   'content_clc_std_mnt3',
#   'all_roam_clc_td_mnt3',
#   'voice_in_td_cnt_std_mnt3',
#   'voice_in_life_part_min_mnt3',
#   'sms_in_cnt_max_mnt3',
#   'voice_in_cmpttrs_td_cnt_min_mnt3',
#   'accum_oth_dur_min_mnt1',
#   'voice_out_td_cnt_min_mnt3',
#   'gprs_tar_vol_min_mnt3',
#   'voice_mts_out_dwork_partmin_mnt3',
#   'content_cnt_min_mnt1',
#   'voice_mts_in_nwork_part_max_mnt3',
#   'pay_max_std_mnt3',
#   'all_clc_std_mnt1',
#   'data_3g_tv_cnt_min_mnt1',
#   'non_accum_internet_vol_td_mnt3',
#   'data_3g_tv_cnt_mea_mnt3',
#   'ama_volume_min_mnt3',
#   'ks_num_part_max_mnt1',
#   'voice_out_cmpttrs_avg_dutd_mnt3',
#   'data_3g_tar_vol_mea_wk1',
#   'voice_out_cmpttrs_avg_dumax_mnt3',
#   'voice_mts_in_nrest_part_max_mnt1',
#   'voice_mts_in_nrest_part_std_mnt3',
#   'sms_clc_min_mnt1',
#   'all_cnt_max_mnt1',
#   'voice_mts_in_nrest_part_min_mnt3',
#   'voice_in_kievstar_part_max_mnt1',
#   'all_clc_max_mnt3',
#   'conn_in_uniq_cnt_mea_mnt1',
#   'clc_no_vas_roam_min_mnt3',
#   'voice_in_short_part_mea_wk1',
#   'accum_mts_dur_mea_mnt1',
#   'voice_mts_in_nwork_part_min_mnt3',
#   'ks_num_part_mea_mnt3',
#   'conn_in_uniq_cnt_std_mnt1',
#   'voice_in_cmpttrs_avg_durmea_mnt3',
#   'vas_clc_std_mnt3',
#   'voice_in_kievstar_part_min_mnt3',
#   'voice_mts_in_nwork_part_std_mnt1',
#   'voice_mts_in_dwork_part_min_mnt3',
#   'gprs_tar_vol_std_mnt1',
#   'voice_out_fix_tar_dur_std_mnt3',
#   'voice_mts_out_nwork_partmea_mnt3',
#   'voice_in_mts_avg_dur_std_mnt3',
#   'block_all_dur_mea_wk1',
#   'voice_in_life_part_mea_wk1',
#   'sms_in_cnt_mea_wk1',
#   'voice_in_kievstar_part_mea_mnt3',
#   'voice_mts_out_nrest_partstd_mnt1',
#   'content_clc_max_mnt3',
#   'gprs_tar_vol_mea_mnt1',
#   'pay_p2p_in_sum_td_mnt3',
#   'voice_out_td_cnt_std_mnt1',
#   'voice_mts_in_drest_part_mea_mnt3',
#   'voice_in_roam_clc_max_mnt1',
#   'data_3g_tv_cnt_mea_mnt1',
#   'pay_p2p_out_sum_min_mnt3',
#   'voice_in_cmpttrs_td_cnt_mea_wk1',
#   'accum_oth_dur_std_mnt3',
#   'ama_volume_mea_wk1',
#   'voice_mts_in_dwork_part_max_mnt1',
#   'num_act_days_min_mnt3',
#   'pay_avg_mea_wk1',
#   'data_3g_tv_cnt_max_mnt3',
#   'all_roam_clc_max_mnt1',
#   'voice_mts_in_dwork_part_std_mnt3',
#   'voice_mts_out_nwork_parttd_mnt3',
#   'data_3g_dou_mea_mnt1',
#   'non_accum_internet_vol_std_mnt3',
#   'content_clc_std_mnt1',
#   'content_clc_mea_wk1',
#   'conn_com_part_mea_mnt3',
#   'voice_in_life_part_td_mnt3',
#   'pay_avg_std_mnt3',
#   'voice_out_cmpttrs_td_cntmax_mnt1',
#   'voice_in_short_part_mea_mnt1',
#   'voice_in_tar_dur_min_mnt3',
#   'gprs_tar_vol_max_mnt3',
#   'vas_clc_mea_mnt3',
#   'voice_out_cmpttrs_td_cntmin_mnt1',
#   'data_3g_tar_vol_max_mnt3',
#   'non_accum_internet_vol_min_mnt3',
#   'gprs_tar_vol_max_mnt1',
#   'conn_com_part_std_mnt1',
#   'voice_out_td_cnt_std_mnt3',
#   'voice_in_mts_avg_dur_td_mnt3',
#   'voice_out_cmpttrs_avg_dumea_mnt1',
#   'voice_out_cmpttrs_td_cntmea_mnt3',
#   'pay_p2p_out_sum_mea_wk1',
#   'com_num_part_mea_wk1',
#   'gprs_tar_vol_mea_mnt3',
#   'conn_in_uniq_cnt_mea_mnt3',
#   'voice_mts_out_nrest_partmea_wk1',
#   'voice_in_fix_tar_dur_min_mnt1',
#   'voice_in_short_part_std_mnt3',
#   'accum_oth_dur_std_mnt1',
#   'accum_mts_dur_max_mnt1',
#   'data_3g_tar_vol_min_mnt1',
#   'voice_out_cmpttrs_td_cntmax_mnt3',
#   'voice_in_mts_avg_dur_mea_mnt1',
#   'abon_part_mea_mnt1',
#   'vas_clc_std_mnt1',
#   'data_3g_tv_cnt_min_mnt3',
#   'pay_avg_mea_mnt3',
#   'abon_part_mea_mnt3',
#   'ks_num_part_max_mnt3',
#   'num_act_days_mea_mnt3',
#   'voice_in_mts_avg_dur_max_mnt3',
#   'conn_com_part_max_mnt1',
#   'voice_in_life_part_std_mnt3',
#   'block_all_dur_mea_mnt3',
#   'voice_in_short_part_std_mnt1',
#   'accum_mts_dur_std_mnt1',
#   'num_act_days_mea_mnt1',
#   'sms_clc_mea_mnt1',
#   'accum_mts_dur_mea_wk1',
#   'abon_part_max_mnt1',
#   'content_cnt_max_mnt3',
#   'pay_avg_max_mnt1',
#   'voice_in_cmpttrs_avg_durtd_mnt3',
#   'all_home_clc_max_mnt3',
#   'block_all_dur_max_mnt3',
#   'voice_in_kievstar_part_mea_mnt1',
#   'voice_mts_in_dwork_part_mea_mnt3',
#   'clc_no_vas_roam_max_mnt1',
#   'voice_out_fix_tar_dur_mea_mnt3',
#   'voice_in_tar_dur_max_mnt1',
#   'sms_out_cnt_max_mnt3',
#   'data_3g_tar_vol_max_mnt1',
#   'abon_part_std_mnt1',
#   'pay_max_max_mnt3',
#   'content_cnt_std_mnt3',
#   'voice_in_life_part_std_mnt1',
#   'non_accum_internet_vol_max_mnt3',
#   'voice_in_cmpttrs_avg_durmax_mnt1',
#   'voice_in_td_cnt_td_mnt3',
#   'accum_oth_dur_mea_wk1',
#   'voice_in_life_part_max_mnt1',
#   'block_all_dur_mea_mnt1',
#   'all_clc_std_mnt3',
#   'voice_in_kievstar_part_mea_wk1',
#   'voice_in_life_part_max_mnt3',
#   'block_all_dur_td_mnt3',
#   'num_act_days_max_mnt3',
#   'voice_mts_in_nwork_part_mea_mnt1',
#   'voice_out_short_part_std_mnt1',
#   'voice_in_tar_dur_mea_wk1',
#   'all_cnt_mea_wk1',
#   'voice_mts_out_drest_parttd_mnt3',
#   'voice_in_roam_clc_td_mnt3',
#   'voice_mts_in_nwork_part_mea_wk1',
#   'voice_in_life_part_min_mnt1',
#   'voice_mts_in_dwork_part_max_mnt3',
#   'accum_oth_dur_td_mnt3',
#   'voice_mts_out_dwork_partmea_mnt1',
#   'content_cnt_min_mnt3',
#   'data_3g_tv_cnt_td_mnt3',
#   'voice_in_mts_avg_dur_mea_wk1',
#   'voice_mts_in_drest_part_max_mnt1',
#   'pay_avg_min_mnt1',
#   'conn_out_uniq_cnt_max_mnt1',
#   'voice_mts_out_nwork_partmea_wk1',
#   'voice_out_tar_dur_mea_mnt3',
#   'sms_out_cnt_std_mnt1',
#   'non_accum_internet_vol_mea_mnt1',
#   'voice_in_td_cnt_min_mnt3',
#   'voice_in_td_cnt_min_mnt1',
#   'content_clc_max_mnt1',
#   'num_act_days_min_mnt1',
#   'sms_in_cnt_max_mnt1',
#   'voice_in_roam_clc_max_mnt3',
#   'pay_sum_mea_wk1',
#   'voice_mts_out_nwork_partstd_mnt3',
#   'all_cnt_std_mnt3',
#   'voice_mts_in_nwork_part_std_mnt3',
#   'sms_out_cnt_min_mnt3',
#   'pay_max_std_mnt1',
#   'voice_out_td_cnt_max_mnt3',
#   'pay_max_min_mnt1',
#   'pay_sum_max_mnt3',
#   'voice_out_cmpttrs_td_cntstd_mnt3',
#   'voice_in_td_cnt_mea_wk1',
#   'voice_in_mts_avg_dur_min_mnt3',
#   'voice_mts_out_nrest_partmea_mnt1',
#   'voice_in_fix_tar_dur_max_mnt3',
#   'abon_part_td_mnt3',
#   'all_home_clc_std_mnt1',
#   'voice_out_fix_tar_dur_min_mnt3',
#   'block_all_dur_std_mnt3',
#   'com_num_part_std_mnt1',
#   'voice_mts_in_nwork_part_mea_mnt3',
#   'sms_in_cnt_std_mnt1',
#   'voice_mts_out_drest_partmin_mnt3',
#   'non_accum_internet_vol_mea_mnt3',
#   'accum_oth_dur_max_mnt1',
#   'pay_p2p_out_sum_td_mnt3',
#   'voice_out_tar_dur_std_mnt3',
#   'data_3g_dou_std_mnt1',
#   'voice_mts_in_drest_part_std_mnt3',
#   'block_all_dur_max_mnt1',
#   'voice_in_life_part_mea_mnt3',
#   'pay_sum_mea_mnt1',
#   'voice_out_short_part_mea_mnt1',
#   'ama_volume_max_mnt1',
#   'pay_max_td_mnt3',
#   'voice_in_short_part_td_mnt3',
#   'ama_volume_std_mnt3',
#   'conn_com_part_mea_mnt1',
#   'voice_in_cmpttrs_avg_durstd_mnt3',
#   'voice_out_cmpttrs_avg_dumin_mnt3',
#   'sms_in_cnt_std_mnt3',
#   'voice_out_tar_dur_mea_mnt1',
#   'conn_com_part_max_mnt3',
#   'sms_clc_mea_mnt3',
#   'com_num_part_std_mnt3',
#   'voice_out_cmpttrs_avg_dumin_mnt1',
#   'voice_mts_out_nrest_partmin_mnt3',
#   'all_cnt_max_mnt3',
#   'sms_clc_max_mnt1',
#   'bs_count_ppm_mn3',
#   'days_of_end_last_ppm',
#   'days_of_last_ppm',
#   'active_ppm',
#   'Balance_uah',
#   'TM_ID',
#   'lt',
#   'loc_is_obl_center',
#   'loc_cnt_events',
#   'loc_market_share',
#   'device_sim_count',
#   'device_days_usage',
#   'device_has_wifi',
#   'device_brand_nan',
#   'device_type_tablet',
#   'device_brand_xiaomi',
#   'imei_mean_price',
#   'device_brand_meizu',
#   'imei_max_price',
#   'device_has_lte',
#   'device_brand_lg',
#   'device_brand_samsung',
#   'device_brand_other',
#   'device_type_nan',
#   'imei_mean_days_usage',
#   'device_type_smartphone',
#   'device_type_rus_other',
#   'imei_mean_day_announced',
#   'device_brand_huawei',
#   'imei_mean_long_days_usage',
#   'device_brand_apple',
#   'device_width_mm',
#   'device_brand_prestigio',
#   'device_type_module',
#   'device_brand_nokia',
#   'device_type_modem',
#   'device_height_mm',
#   'device_brand_sony',
#   'device_brand_lenovo',
#   'device_type_phone',
#   'std_paym_6_month',
#   'max_paym_6_month',
#   'avg_paym_6_month',
#   'count_day_for_last_paym',
#   'is_max_paym',
#   'cnt_paym_6_month',
#   'is_avg_paym',
#   'last_paym',
#   'min_paym_6_month',
#   'sum_paym_6_month',
#   'bs_ovrl_OMO_SUM_M1',
#   'bs_ovrl_OMO_CNT_M1',
#   'MV_Traf_Cont_out_v_Min',
#   'MV_ot_mn_out_v',
#   'MV_dou_Roam_v',
#   'MV_dou_out_s',
#   'MV_ot_omo_out_v',
#   'MV_ARPU_omo_out_s_Traf',
#   'MV_Traf_innet_out_s_Cnt',
#   'MV_ARPU_R_out_v_Traf',
#   'MV_ARPU_mn_out_v_Traf',
#   'MV_ARPU_omo_out_v_Traf',
#   'MV_Traf_R_out_v_Min',
#   'MV_Traf_3G_d_Mb',
#   'MV_Traf_2G_d_Mb',
#   'MV_ARPU_R_out_s_Traf',
#   'MV_ot_3G_d',
#   'MV_dou_Roam_d',
#   'MV_ARPU_Roam_d_Traf',
#   'MV_dou_innet_out_v',
#   'MV_Traf_omo_inc_v_Min',
#   'MV_dou_net',
#   'MV_dou',
#   'MV_Traf_Cont_out_s_Cnt',
#   'MV_Traf_4G_d_Mb',
#   'MV_ot_R_v',
#   'MV_Traf_innet_out_v_Min',
#   'MV_Traf_Other_inc_v_Min',
#   'MV_Traf_omo_out_v_Min',
#   'MV_Traf_pstn_out_v_Min',
#   'MV_net_total',
#   'MV_ot_Cont_v',
#   'MV_Traf_Cont_inc_s_Cnt',
#   'MV_Traf_Roam_d_Mb',
#   'MV_ARPU_3G_d_Traf',
#   'MV_dou_4G_d',
#   'MV_ARPU_4G_d_Traf',
#   'MV_ARPU_Cont_out_s_Traf',
#   'MV_ARPU_Cont_out_v_Traf',
#   'MV_ot_Unkn',
#   'MV_ot_Roam_d',
#   'MV_Traf_R_inc_v_Min',
#   'MV_Traf_mn_inc_v_Min',
#   'MV_dou_3G_d',
#   'MV_ot_4G_d',
#   'MV_ARPU_pstn_out_v_Traf',
#   'MV_ARPU_innet_out_s_Traf',
#   'MV_ARPU_mn_out_s_Traf',
#   'MV_Traf_inc_s_Cnt',
#   'MV_Traf_mn_out_s_Cnt',
#   'MV_Traf_R_out_s_Cnt',
#   'MV_Traf_innet_inc_v_Min',
#   'MV_ARPU_innet_out_v_Traf',
#   'MV_ot_pstn_out_v',
#   'MV_dou_data',
#   'MV_dou_mn_out_v',
#   'MV_ot_s',
#   'MV_ARPU',
#   'MV_dou_omo_out_v',
#   'MV_ARPU_inc_s_Traf',
#   'MV_ot_innet_out_v',
#   'MV_dou_Roam',
#   'MV_Traf_omo_out_s_Cnt',
#   'MV_dou_2G_d',
#   'MV_Traf_pstn_inc_v_Min',
#   'MV_ARPU_R_inc_v_Traf',
#   'MV_ARPU_2G_d_Traf',
#   'MV_ot_Other',
#   'MV_Traf_ACCA_out_v_Min',
#   'MV_Traf_mn_out_v_Min',
#   'MV_DOU_OT',
#   'MV_Migr_To',
#   'MV_ot_total',
#   'abon_id',
#   'call_cnt_out',
#   'call_cnt_in',
#   'call_dur_out',
#   'call_dur_in',
#   'cnt_sms_out',
#   'cnt_sms_in',
#   'SUM_of_Duration_sec',
#   'SUM_of_Volume_kb',
#   'SUM_of_Count_events',
#   'MAX_of_day_cnt',
#   'missingindicator_bs_count_ppm_mn3',
#   'missingindicator_days_of_end_last_ppm',
#   'missingindicator_days_of_last_ppm',
#   'missingindicator_active_ppm',
#   'missingindicator_lt',
#   'missingindicator_loc_is_obl_center',
#   'missingindicator_loc_cnt_events',
#   'missingindicator_loc_market_share',
#   'missingindicator_device_sim_count',
#   'missingindicator_device_days_usage',
#   'missingindicator_device_has_wifi',
#   'missingindicator_device_brand_nan',
#   'missingindicator_device_type_tablet',
#   'missingindicator_device_brand_xiaomi',
#   'missingindicator_imei_mean_price',
#   'missingindicator_device_brand_meizu',
#   'missingindicator_imei_max_price',
#   'missingindicator_device_has_lte',
#   'missingindicator_device_brand_lg',
#   'missingindicator_device_brand_samsung',
#   'missingindicator_device_brand_other',
#   'missingindicator_device_type_nan',
#   'missingindicator_imei_mean_days_usage',
#   'missingindicator_device_type_smartphone',
#   'missingindicator_device_type_rus_other',
#   'missingindicator_imei_mean_day_announced',
#   'missingindicator_device_brand_huawei',
#   'missingindicator_imei_mean_long_days_usage',
#   'missingindicator_device_brand_apple',
#   'missingindicator_device_width_mm',
#   'missingindicator_device_brand_prestigio',
#   'missingindicator_device_type_module',
#   'missingindicator_device_brand_nokia',
#   'missingindicator_device_type_modem',
#   'missingindicator_device_height_mm',
#   'missingindicator_device_brand_sony',
#   'missingindicator_device_brand_lenovo',
#   'missingindicator_device_type_phone',
#   'missingindicator_std_paym_6_month',
#   'missingindicator_max_paym_6_month',
#   'missingindicator_avg_paym_6_month',
#   'missingindicator_count_day_for_last_paym',
#   'missingindicator_is_max_paym',
#   'missingindicator_cnt_paym_6_month',
#   'missingindicator_is_avg_paym',
#   'missingindicator_last_paym',
#   'missingindicator_min_paym_6_month',
#   'missingindicator_sum_paym_6_month',
#   'missingindicator_bs_ovrl_OMO_SUM_M1',
#   'missingindicator_bs_ovrl_OMO_CNT_M1',
#   'missingindicator_MV_Traf_Cont_out_v_Min',
#   'missingindicator_MV_ot_mn_out_v',
#   'missingindicator_MV_dou_Roam_v',
#   'missingindicator_MV_dou_out_s',
#   'missingindicator_MV_ot_omo_out_v',
#   'missingindicator_MV_ARPU_omo_out_s_Traf',
#   'missingindicator_MV_Traf_innet_out_s_Cnt',
#   'missingindicator_MV_ARPU_R_out_v_Traf',
#   'missingindicator_MV_ARPU_mn_out_v_Traf',
#   'missingindicator_MV_ARPU_omo_out_v_Traf',
#   'missingindicator_MV_Traf_Other_out_v_Min',
#   'missingindicator_MV_Traf_R_out_v_Min',
#   'missingindicator_MV_Traf_3G_d_Mb',
#   'missingindicator_MV_Traf_2G_d_Mb',
#   'missingindicator_MV_ARPU_R_out_s_Traf',
#   'missingindicator_MV_ot_3G_d',
#   'missingindicator_MV_dou_Roam_d',
#   'missingindicator_MV_ARPU_Roam_d_Traf',
#   'missingindicator_MV_dou_innet_out_v',
#   'missingindicator_MV_Traf_omo_inc_v_Min',
#   'missingindicator_MV_ARPU_Other_out_v_Traf',
#   'missingindicator_MV_dou_net',
#   'missingindicator_MV_dou',
#   'missingindicator_MV_Traf_Cont_out_s_Cnt',
#   'missingindicator_MV_ARPU_Other_inc_v_Traf',
#   'missingindicator_MV_Traf_4G_d_Mb',
#   'missingindicator_MV_ot_R_v',
#   'missingindicator_MV_Traf_innet_out_v_Min',
#   'missingindicator_MV_Traf_Other_inc_v_Min',
#   'missingindicator_MV_Traf_omo_out_v_Min',
#   'missingindicator_MV_Traf_pstn_out_v_Min',
#   'missingindicator_MV_net_total',
#   'missingindicator_MV_ot_Cont_v',
#   'missingindicator_MV_Traf_Cont_inc_s_Cnt',
#   'missingindicator_MV_Traf_Cont_inc_v_Min',
#   'missingindicator_MV_Traf_Roam_d_Mb',
#   'missingindicator_MV_ARPU_3G_d_Traf',
#   'missingindicator_MV_dou_4G_d',
#   'missingindicator_MV_ARPU_4G_d_Traf',
#   'missingindicator_MV_ot_R_sm',
#   'missingindicator_MV_ARPU_Cont_out_s_Traf',
#   'missingindicator_MV_ARPU_Cont_out_v_Traf',
#   'missingindicator_MV_ot_Unkn',
#   'missingindicator_MV_ot_Roam_d',
#   'missingindicator_MV_Traf_R_inc_v_Min',
#   'missingindicator_MV_Traf_mn_inc_v_Min',
#   'missingindicator_MV_dou_3G_d',
#   'missingindicator_MV_ot_4G_d',
#   'missingindicator_MV_ARPU_pstn_out_v_Traf',
#   'missingindicator_MV_ARPU_innet_out_s_Traf',
#   'missingindicator_MV_ARPU_mn_out_s_Traf',
#   'missingindicator_MV_Traf_inc_s_Cnt',
#   'missingindicator_MV_Traf_mn_out_s_Cnt',
#   'missingindicator_MV_ARPU_innet_inc_v_Traf',
#   'missingindicator_MV_Traf_R_out_s_Cnt',
#   'missingindicator_MV_Traf_innet_inc_v_Min',
#   'missingindicator_MV_ot_inc_v',
#   'missingindicator_MV_ARPU_innet_out_v_Traf',
#   'missingindicator_MV_ot_pstn_out_v',
#   'missingindicator_MV_dou_data',
#   'missingindicator_MV_dou_mn_out_v',
#   'missingindicator_MV_ot_s',
#   'missingindicator_MV_ARPU',
#   'missingindicator_MV_dou_omo_out_v',
#   'missingindicator_MV_ARPU_inc_s_Traf',
#   'missingindicator_MV_ot_innet_out_v',
#   'missingindicator_MV_dou_Roam',
#   'missingindicator_MV_Traf_omo_out_s_Cnt',
#   'missingindicator_MV_dou_2G_d',
#   'missingindicator_MV_Traf_pstn_inc_v_Min',
#   'missingindicator_MV_ARPU_R_inc_v_Traf',
#   'missingindicator_MV_ARPU_2G_d_Traf',
#   'missingindicator_MV_ot_Other',
#   'missingindicator_MV_Traf_ACCA_out_v_Min',
#   'missingindicator_MV_Traf_mn_out_v_Min',
#   'missingindicator_MV_DOU_OT',
#   'missingindicator_MV_Migr_To',
#   'missingindicator_MV_ot_total'],
#  'k_best_features': ['content_cnt_max_mnt1',
#   'num_act_days_max_mnt1',
#   'voice_out_tar_dur_std_mnt1',
#   'voice_out_tar_dur_min_mnt1',
#   'voice_in_tar_dur_max_mnt3',
#   'voice_mts_out_drest_partmea_mnt1',
#   'voice_mts_in_dwork_part_mea_wk1',
#   'voice_mts_in_dwork_part_std_mnt1',
#   'voice_in_tar_dur_std_mnt1',
#   'voice_mts_out_dwork_partmea_wk1',
#   'voice_in_tar_dur_std_mnt3',
#   'voice_in_td_cnt_max_mnt3',
#   'content_cnt_mea_mnt1',
#   'voice_mts_out_drest_partstd_mnt3',
#   'voice_in_td_cnt_mea_mnt3',
#   'conn_in_uniq_cnt_mea_wk1',
#   'all_cnt_min_mnt1',
#   'all_cnt_mea_mnt1',
#   'voice_mts_out_dwork_partstd_mnt1',
#   'voice_mts_in_dwork_part_min_mnt1',
#   'pay_max_mea_mnt3',
#   'voice_in_mts_avg_dur_max_mnt1',
#   'voice_in_td_cnt_mea_mnt1',
#   'voice_mts_in_drest_part_max_mnt3',
#   'voice_mts_in_nrest_part_mea_mnt3',
#   'voice_out_tar_dur_max_mnt1',
#   'voice_mts_in_drest_part_std_mnt1',
#   'voice_in_td_cnt_max_mnt1',
#   'conn_in_uniq_cnt_max_mnt1',
#   'conn_out_uniq_cnt_mea_mnt1',
#   'conn_in_uniq_cnt_min_mnt1',
#   'voice_in_tar_dur_mea_mnt3',
#   'voice_mts_out_dwork_partmea_mnt3',
#   'voice_out_tar_dur_max_mnt3',
#   'voice_mts_in_drest_part_mea_wk1',
#   'all_cnt_mea_mnt3',
#   'voice_out_tar_dur_mea_wk1',
#   'voice_mts_in_dwork_part_mea_mnt1',
#   'voice_in_mts_avg_dur_min_mnt1',
#   'voice_in_tar_dur_mea_mnt1',
#   'voice_mts_out_nwork_partmax_mnt3',
#   'voice_mts_out_dwork_partmin_mnt1',
#   'num_act_days_std_mnt3',
#   'voice_mts_in_nwork_part_max_mnt1',
#   'num_act_days_mea_wk1',
#   'voice_mts_in_drest_part_mea_mnt1',
#   'content_cnt_mea_mnt3',
#   'voice_in_mts_avg_dur_mea_mnt3',
#   'voice_mts_out_drest_partmax_mnt3',
#   'voice_mts_out_drest_partmea_mnt3',
#   'voice_mts_out_dwork_partmax_mnt3',
#   'voice_mts_out_drest_partmax_mnt1',
#   'num_act_days_std_mnt1',
#   'all_cnt_min_mnt3',
#   'voice_out_tar_dur_min_mnt3',
#   'voice_in_tar_dur_min_mnt1',
#   'voice_mts_out_dwork_partmax_mnt1',
#   'voice_mts_out_dwork_partstd_mnt3',
#   'voice_mts_out_drest_partstd_mnt1',
#   'voice_mts_in_nwork_part_max_mnt3',
#   'voice_mts_in_nrest_part_std_mnt3',
#   'conn_in_uniq_cnt_mea_mnt1',
#   'voice_mts_in_nwork_part_std_mnt1',
#   'voice_mts_in_dwork_part_min_mnt3',
#   'voice_mts_out_nwork_partmea_mnt3',
#   'voice_mts_in_drest_part_mea_mnt3',
#   'voice_mts_in_dwork_part_max_mnt1',
#   'num_act_days_min_mnt3',
#   'voice_mts_in_dwork_part_std_mnt3',
#   'voice_in_tar_dur_min_mnt3',
#   'voice_in_mts_avg_dur_mea_mnt1',
#   'pay_avg_mea_mnt3',
#   'num_act_days_mea_mnt3',
#   'voice_in_mts_avg_dur_max_mnt3',
#   'num_act_days_mea_mnt1',
#   'voice_mts_in_dwork_part_mea_mnt3',
#   'voice_in_tar_dur_max_mnt1',
#   'num_act_days_max_mnt3',
#   'voice_mts_in_nwork_part_mea_mnt1',
#   'voice_in_tar_dur_mea_wk1',
#   'all_cnt_mea_wk1',
#   'voice_mts_in_dwork_part_max_mnt3',
#   'voice_mts_out_dwork_partmea_mnt1',
#   'voice_in_mts_avg_dur_mea_wk1',
#   'voice_mts_in_drest_part_max_mnt1',
#   'conn_out_uniq_cnt_max_mnt1',
#   'voice_out_tar_dur_mea_mnt3',
#   'voice_in_td_cnt_min_mnt1',
#   'num_act_days_min_mnt1',
#   'voice_mts_out_nwork_partstd_mnt3',
#   'voice_mts_in_nwork_part_std_mnt3',
#   'voice_in_td_cnt_mea_wk1',
#   'voice_in_mts_avg_dur_min_mnt3',
#   'voice_mts_in_nwork_part_mea_mnt3',
#   'voice_out_tar_dur_std_mnt3',
#   'voice_mts_in_drest_part_std_mnt3',
#   'voice_out_tar_dur_mea_mnt1',
#   'days_of_end_last_ppm',
#   'active_ppm',
#   'loc_cnt_events',
#   'device_sim_count',
#   'device_days_usage',
#   'device_brand_other',
#   'device_type_smartphone',
#   'device_type_rus_other',
#   'device_width_mm',
#   'device_height_mm',
#   'sum_paym_6_month',
#   'MV_dou_innet_out_v',
#   'MV_dou_net',
#   'MV_dou',
#   'MV_Traf_innet_out_v_Min',
#   'MV_Traf_Cont_inc_s_Cnt',
#   'MV_Traf_innet_inc_v_Min',
#   'missingindicator_device_sim_count',
#   'missingindicator_device_days_usage',
#   'missingindicator_device_has_wifi',
#   'missingindicator_device_brand_nan',
#   'missingindicator_device_type_tablet',
#   'missingindicator_device_brand_xiaomi',
#   'missingindicator_device_brand_meizu',
#   'missingindicator_device_has_lte',
#   'missingindicator_device_brand_lg',
#   'missingindicator_device_brand_samsung',
#   'missingindicator_device_brand_other',
#   'missingindicator_device_type_nan',
#   'missingindicator_device_type_smartphone',
#   'missingindicator_device_type_rus_other',
#   'missingindicator_device_brand_huawei',
#   'missingindicator_device_brand_apple',
#   'missingindicator_device_width_mm',
#   'missingindicator_device_brand_prestigio',
#   'missingindicator_device_type_module',
#   'missingindicator_device_brand_nokia',
#   'missingindicator_device_type_modem',
#   'missingindicator_device_height_mm',
#   'missingindicator_device_brand_sony',
#   'missingindicator_device_brand_lenovo',
#   'missingindicator_device_type_phone',
#   'missingindicator_MV_Traf_Cont_out_v_Min',
#   'missingindicator_MV_dou_Roam_v',
#   'missingindicator_MV_dou_out_s',
#   'missingindicator_MV_ARPU_omo_out_s_Traf',
#   'missingindicator_MV_Traf_innet_out_s_Cnt',
#   'missingindicator_MV_ARPU_R_out_v_Traf',
#   'missingindicator_MV_ARPU_mn_out_v_Traf',
#   'missingindicator_MV_ARPU_omo_out_v_Traf',
#   'missingindicator_MV_Traf_Other_out_v_Min',
#   'missingindicator_MV_Traf_R_out_v_Min',
#   'missingindicator_MV_Traf_3G_d_Mb',
#   'missingindicator_MV_Traf_2G_d_Mb',
#   'missingindicator_MV_ARPU_R_out_s_Traf',
#   'missingindicator_MV_dou_Roam_d',
#   'missingindicator_MV_ARPU_Roam_d_Traf',
#   'missingindicator_MV_dou_innet_out_v',
#   'missingindicator_MV_Traf_omo_inc_v_Min',
#   'missingindicator_MV_ARPU_Other_out_v_Traf',
#   'missingindicator_MV_dou_net',
#   'missingindicator_MV_dou',
#   'missingindicator_MV_Traf_Cont_out_s_Cnt',
#   'missingindicator_MV_ARPU_Other_inc_v_Traf',
#   'missingindicator_MV_Traf_4G_d_Mb',
#   'missingindicator_MV_Traf_innet_out_v_Min',
#   'missingindicator_MV_Traf_Other_inc_v_Min',
#   'missingindicator_MV_Traf_omo_out_v_Min',
#   'missingindicator_MV_Traf_pstn_out_v_Min',
#   'missingindicator_MV_net_total',
#   'missingindicator_MV_Traf_Cont_inc_s_Cnt',
#   'missingindicator_MV_Traf_Cont_inc_v_Min',
#   'missingindicator_MV_Traf_Roam_d_Mb',
#   'missingindicator_MV_ARPU_3G_d_Traf',
#   'missingindicator_MV_dou_4G_d',
#   'missingindicator_MV_ARPU_4G_d_Traf',
#   'missingindicator_MV_ARPU_Cont_out_s_Traf',
#   'missingindicator_MV_ARPU_Cont_out_v_Traf',
#   'missingindicator_MV_Traf_R_inc_v_Min',
#   'missingindicator_MV_Traf_mn_inc_v_Min',
#   'missingindicator_MV_dou_3G_d',
#   'missingindicator_MV_ARPU_pstn_out_v_Traf',
#   'missingindicator_MV_ARPU_innet_out_s_Traf',
#   'missingindicator_MV_ARPU_mn_out_s_Traf',
#   'missingindicator_MV_Traf_inc_s_Cnt',
#   'missingindicator_MV_Traf_mn_out_s_Cnt',
#   'missingindicator_MV_ARPU_innet_inc_v_Traf',
#   'missingindicator_MV_Traf_R_out_s_Cnt',
#   'missingindicator_MV_Traf_innet_inc_v_Min',
#   'missingindicator_MV_ARPU_innet_out_v_Traf',
#   'missingindicator_MV_dou_data',
#   'missingindicator_MV_dou_mn_out_v',
#   'missingindicator_MV_ARPU',
#   'missingindicator_MV_dou_omo_out_v',
#   'missingindicator_MV_ARPU_inc_s_Traf',
#   'missingindicator_MV_dou_Roam',
#   'missingindicator_MV_Traf_omo_out_s_Cnt',
#   'missingindicator_MV_dou_2G_d',
#   'missingindicator_MV_Traf_pstn_inc_v_Min',
#   'missingindicator_MV_ARPU_R_inc_v_Traf',
#   'missingindicator_MV_ARPU_2G_d_Traf',
#   'missingindicator_MV_Traf_ACCA_out_v_Min',
#   'missingindicator_MV_Traf_mn_out_v_Min'],
#  'features_from_model': ['content_cnt_max_mnt1',
#   'num_act_days_max_mnt1',
#   'com_num_part_mea_mnt1',
#   'voice_out_tar_dur_std_mnt1',
#   'voice_in_short_part_mea_mnt3',
#   'conn_out_uniq_cnt_std_mnt1',
#   'voice_mts_in_dwork_part_td_mnt3',
#   'data_3g_tar_vol_mea_mnt3',
#   'voice_in_fix_tar_dur_mea_mnt3',
#   'voice_in_tar_dur_max_mnt3',
#   'ks_num_part_td_mnt3',
#   'data_3g_dou_mea_mnt3',
#   'voice_mts_in_dwork_part_mea_wk1',
#   'voice_mts_in_dwork_part_std_mnt1',
#   'conn_com_part_td_mnt3',
#   'voice_in_cmpttrs_avg_durmax_mnt3',
#   'voice_in_tar_dur_td_mnt3',
#   'conn_in_uniq_cnt_td_mnt3',
#   'voice_in_tar_dur_std_mnt1',
#   'voice_out_cmpttrs_td_cnttd_mnt3',
#   'voice_in_tar_dur_std_mnt3',
#   'voice_in_td_cnt_max_mnt3',
#   'conn_com_part_std_mnt3',
#   'content_cnt_mea_mnt1',
#   'all_home_clc_td_mnt3',
#   'voice_out_td_cnt_mea_mnt1',
#   'com_num_part_max_mnt1',
#   'voice_mts_out_drest_partstd_mnt3',
#   'pay_sum_td_mnt3',
#   'conn_out_uniq_cnt_std_mnt3',
#   'voice_in_cmpttrs_td_cnt_max_mnt1',
#   'voice_in_td_cnt_mea_mnt3',
#   'ks_num_part_mea_wk1',
#   'voice_in_cmpttrs_td_cnt_max_mnt3',
#   'conn_in_uniq_cnt_mea_wk1',
#   'voice_in_td_cnt_std_mnt1',
#   'all_cnt_min_mnt1',
#   'accum_mts_dur_std_mnt3',
#   'data_3g_tv_cnt_mea_wk1',
#   'data_3g_tar_vol_mea_mnt1',
#   'all_cnt_mea_mnt1',
#   'data_3g_dou_std_mnt3',
#   'sms_in_cnt_td_mnt3',
#   'voice_mts_out_dwork_partstd_mnt1',
#   'pay_sum_max_mnt1',
#   'content_cnt_mea_wk1',
#   'com_num_part_mea_mnt3',
#   'conn_out_uniq_cnt_max_mnt3',
#   'conn_out_uniq_cnt_mea_mnt3',
#   'all_cnt_std_mnt1',
#   'conn_com_part_mea_wk1',
#   'com_num_part_max_mnt3',
#   'vas_clc_max_mnt3',
#   'data_3g_tar_vol_std_mnt1',
#   'sms_in_cnt_mea_mnt1',
#   'com_num_part_td_mnt3',
#   'all_home_clc_mea_mnt3',
#   'voice_in_short_part_max_mnt3',
#   'pay_max_max_mnt1',
#   'all_clc_mea_mnt3',
#   'voice_mts_in_drest_part_td_mnt3',
#   'voice_mts_in_dwork_part_min_mnt1',
#   'voice_in_cmpttrs_td_cnt_mea_mnt1',
#   'pay_max_mea_mnt3',
#   'ks_num_part_std_mnt1',
#   'voice_in_mts_avg_dur_max_mnt1',
#   'voice_in_td_cnt_mea_mnt1',
#   'voice_mts_in_drest_part_max_mnt3',
#   'voice_mts_in_nrest_part_mea_mnt3',
#   'voice_mts_in_drest_part_std_mnt1',
#   'clc_no_vas_roam_std_mnt3',
#   'non_accum_internet_vol_mea_wk1',
#   'data_3g_dou_td_mnt3',
#   'voice_out_cmpttrs_avg_dustd_mnt3',
#   'voice_in_td_cnt_max_mnt1',
#   'voice_in_kievstar_part_std_mnt3',
#   'gprs_tar_vol_td_mnt3',
#   'accum_mts_dur_mea_mnt3',
#   'conn_in_uniq_cnt_max_mnt1',
#   'pay_sum_std_mnt3',
#   'vas_clc_td_mnt3',
#   'sms_in_cnt_mea_mnt3',
#   'voice_out_short_part_mea_mnt3',
#   'data_3g_tar_vol_std_mnt3',
#   'content_cnt_td_mnt3',
#   'gprs_tar_vol_mea_wk1',
#   'voice_mts_in_nwork_part_td_mnt3',
#   'voice_in_cmpttrs_avg_durmea_mnt1',
#   'non_accum_internet_vol_min_mnt1',
#   'pay_sum_mea_mnt3',
#   'content_cnt_std_mnt1',
#   'conn_in_uniq_cnt_min_mnt1',
#   'voice_in_tar_dur_mea_mnt3',
#   'conn_out_uniq_cnt_mea_wk1',
#   'voice_out_td_cnt_max_mnt1',
#   'voice_in_fix_tar_dur_std_mnt3',
#   'data_3g_tv_cnt_std_mnt3',
#   'voice_mts_out_dwork_partmea_mnt3',
#   'non_accum_internet_vol_std_mnt1',
#   'voice_out_tar_dur_max_mnt3',
#   'voice_in_life_part_mea_mnt1',
#   'voice_in_kievstar_part_td_mnt3',
#   'voice_mts_in_drest_part_mea_wk1',
#   'all_cnt_mea_mnt3',
#   'voice_out_short_part_std_mnt3',
#   'voice_out_tar_dur_mea_wk1',
#   'voice_mts_in_dwork_part_mea_mnt1',
#   'voice_in_kievstar_part_max_mnt3',
#   'clc_no_vas_roam_max_mnt3',
#   'data_3g_dou_max_mnt1',
#   'clc_no_vas_roam_mea_mnt3',
#   'data_3g_dou_max_mnt3',
#   'voice_mts_in_nrest_part_max_mnt3',
#   'voice_in_kievstar_part_std_mnt1',
#   'data_3g_tv_cnt_std_mnt1',
#   'all_clc_max_mnt1',
#   'conn_in_uniq_cnt_max_mnt3',
#   'all_cnt_td_mnt3',
#   'conn_out_uniq_cnt_td_mnt3',
#   'voice_in_tar_dur_mea_mnt1',
#   'voice_in_cmpttrs_td_cnt_std_mnt3',
#   'ks_num_part_mea_mnt1',
#   'voice_out_short_part_max_mnt3',
#   'voice_mts_in_nrest_part_td_mnt3',
#   'conn_in_uniq_cnt_min_mnt3',
#   'data_3g_tv_cnt_max_mnt1',
#   'voice_in_fix_tar_dur_td_mnt3',
#   'num_act_days_std_mnt3',
#   'voice_mts_in_nwork_part_max_mnt1',
#   'num_act_days_td_mnt3',
#   'all_clc_td_mnt3',
#   'num_act_days_mea_wk1',
#   'data_3g_tar_vol_td_mnt3',
#   'voice_in_cmpttrs_avg_durstd_mnt1',
#   'voice_out_td_cnt_mea_mnt3',
#   'voice_in_cmpttrs_td_cnt_td_mnt3',
#   'clc_no_vas_roam_td_mnt3',
#   'conn_in_uniq_cnt_std_mnt3',
#   'non_accum_internet_vol_max_mnt1',
#   'voice_mts_in_drest_part_mea_mnt1',
#   'all_home_clc_std_mnt3',
#   'content_cnt_mea_mnt3',
#   'sms_out_cnt_td_mnt3',
#   'voice_in_mts_avg_dur_mea_mnt3',
#   'voice_out_tar_dur_td_mnt3',
#   'voice_out_cmpttrs_avg_dumea_mnt3',
#   'voice_mts_out_drest_partmax_mnt3',
#   'voice_mts_out_drest_partmea_mnt3',
#   'voice_mts_out_dwork_partmax_mnt3',
#   'ks_num_part_std_mnt3',
#   'pay_avg_max_mnt3',
#   'voice_mts_out_drest_partmax_mnt1',
#   'num_act_days_std_mnt1',
#   'all_cnt_min_mnt3',
#   'voice_in_mts_avg_dur_std_mnt1',
#   'voice_out_td_cnt_td_mnt3',
#   'voice_in_cmpttrs_td_cnt_mea_mnt3',
#   'gprs_tar_vol_std_mnt3',
#   'voice_in_tar_dur_min_mnt1',
#   'pay_avg_td_mnt3',
#   'voice_mts_out_dwork_partmax_mnt1',
#   'voice_mts_out_dwork_partstd_mnt3',
#   'voice_in_td_cnt_std_mnt3',
#   'sms_in_cnt_max_mnt3',
#   'content_cnt_min_mnt1',
#   'voice_mts_in_nwork_part_max_mnt3',
#   'pay_max_std_mnt3',
#   'all_clc_std_mnt1',
#   'non_accum_internet_vol_td_mnt3',
#   'data_3g_tv_cnt_mea_mnt3',
#   'voice_out_cmpttrs_avg_dutd_mnt3',
#   'voice_out_cmpttrs_avg_dumax_mnt3',
#   'voice_mts_in_nrest_part_std_mnt3',
#   'all_cnt_max_mnt1',
#   'voice_in_kievstar_part_max_mnt1',
#   'all_clc_max_mnt3',
#   'conn_in_uniq_cnt_mea_mnt1',
#   'ks_num_part_mea_mnt3',
#   'conn_in_uniq_cnt_std_mnt1',
#   'voice_in_cmpttrs_avg_durmea_mnt3',
#   'vas_clc_std_mnt3',
#   'voice_mts_in_nwork_part_std_mnt1',
#   'gprs_tar_vol_std_mnt1',
#   'voice_mts_out_nwork_partmea_mnt3',
#   'voice_in_mts_avg_dur_std_mnt3',
#   'sms_in_cnt_mea_wk1',
#   'voice_in_kievstar_part_mea_mnt3',
#   'gprs_tar_vol_mea_mnt1',
#   'voice_out_td_cnt_std_mnt1',
#   'voice_mts_in_drest_part_mea_mnt3',
#   'data_3g_tv_cnt_mea_mnt1',
#   'accum_oth_dur_std_mnt3',
#   'voice_mts_in_dwork_part_max_mnt1',
#   'num_act_days_min_mnt3',
#   'data_3g_tv_cnt_max_mnt3',
#   'voice_mts_in_dwork_part_std_mnt3',
#   'data_3g_dou_mea_mnt1',
#   'non_accum_internet_vol_std_mnt3',
#   'conn_com_part_mea_mnt3',
#   'pay_avg_std_mnt3',
#   'gprs_tar_vol_max_mnt3',
#   'vas_clc_mea_mnt3',
#   'data_3g_tar_vol_max_mnt3',
#   'non_accum_internet_vol_min_mnt3',
#   'gprs_tar_vol_max_mnt1',
#   'conn_com_part_std_mnt1',
#   'voice_out_td_cnt_std_mnt3',
#   'voice_in_mts_avg_dur_td_mnt3',
#   'voice_out_cmpttrs_avg_dumea_mnt1',
#   'com_num_part_mea_wk1',
#   'gprs_tar_vol_mea_mnt3',
#   'conn_in_uniq_cnt_mea_mnt3',
#   'voice_in_short_part_std_mnt3',
#   'voice_out_cmpttrs_td_cntmax_mnt3',
#   'voice_in_mts_avg_dur_mea_mnt1',
#   'pay_avg_mea_mnt3',
#   'ks_num_part_max_mnt3',
#   'num_act_days_mea_mnt3',
#   'voice_in_mts_avg_dur_max_mnt3',
#   'conn_com_part_max_mnt1',
#   'voice_in_life_part_std_mnt3',
#   'num_act_days_mea_mnt1',
#   'content_cnt_max_mnt3',
#   'pay_avg_max_mnt1',
#   'voice_in_cmpttrs_avg_durtd_mnt3',
#   'all_home_clc_max_mnt3',
#   'voice_mts_in_dwork_part_mea_mnt3',
#   'voice_in_tar_dur_max_mnt1',
#   'sms_out_cnt_max_mnt3',
#   'data_3g_tar_vol_max_mnt1',
#   'pay_max_max_mnt3',
#   'content_cnt_std_mnt3',
#   'non_accum_internet_vol_max_mnt3',
#   'voice_in_cmpttrs_avg_durmax_mnt1',
#   'voice_in_td_cnt_td_mnt3',
#   'all_clc_std_mnt3',
#   'voice_in_life_part_max_mnt3',
#   'num_act_days_max_mnt3',
#   'voice_mts_in_nwork_part_mea_mnt1',
#   'voice_in_tar_dur_mea_wk1',
#   'all_cnt_mea_wk1',
#   'voice_mts_out_drest_parttd_mnt3',
#   'voice_mts_in_dwork_part_max_mnt3',
#   'voice_mts_out_dwork_partmea_mnt1',
#   'content_cnt_min_mnt3',
#   'data_3g_tv_cnt_td_mnt3',
#   'voice_in_mts_avg_dur_mea_wk1',
#   'voice_mts_in_drest_part_max_mnt1',
#   'conn_out_uniq_cnt_max_mnt1',
#   'voice_out_tar_dur_mea_mnt3',
#   'non_accum_internet_vol_mea_mnt1',
#   'num_act_days_min_mnt1',
#   'sms_in_cnt_max_mnt1',
#   'voice_mts_out_nwork_partstd_mnt3',
#   'all_cnt_std_mnt3',
#   'voice_mts_in_nwork_part_std_mnt3',
#   'voice_out_td_cnt_max_mnt3',
#   'voice_out_cmpttrs_td_cntstd_mnt3',
#   'voice_in_td_cnt_mea_wk1',
#   'voice_in_fix_tar_dur_max_mnt3',
#   'all_home_clc_std_mnt1',
#   'com_num_part_std_mnt1',
#   'voice_mts_in_nwork_part_mea_mnt3',
#   'sms_in_cnt_std_mnt1',
#   'non_accum_internet_vol_mea_mnt3',
#   'voice_out_tar_dur_std_mnt3',
#   'data_3g_dou_std_mnt1',
#   'voice_mts_in_drest_part_std_mnt3',
#   'voice_in_life_part_mea_mnt3',
#   'pay_max_td_mnt3',
#   'voice_in_short_part_td_mnt3',
#   'conn_com_part_mea_mnt1',
#   'voice_in_cmpttrs_avg_durstd_mnt3',
#   'sms_in_cnt_std_mnt3',
#   'voice_out_tar_dur_mea_mnt1',
#   'conn_com_part_max_mnt3',
#   'com_num_part_std_mnt3',
#   'all_cnt_max_mnt3',
#   'bs_count_ppm_mn3',
#   'days_of_end_last_ppm',
#   'days_of_last_ppm',
#   'active_ppm',
#   'Balance_uah',
#   'TM_ID',
#   'lt',
#   'loc_is_obl_center',
#   'loc_cnt_events',
#   'loc_market_share',
#   'device_sim_count',
#   'device_days_usage',
#   'device_brand_xiaomi',
#   'imei_mean_price',
#   'imei_max_price',
#   'device_has_lte',
#   'imei_mean_days_usage',
#   'device_type_rus_other',
#   'imei_mean_day_announced',
#   'imei_mean_long_days_usage',
#   'device_width_mm',
#   'device_height_mm',
#   'std_paym_6_month',
#   'max_paym_6_month',
#   'avg_paym_6_month',
#   'count_day_for_last_paym',
#   'is_max_paym',
#   'cnt_paym_6_month',
#   'is_avg_paym',
#   'last_paym',
#   'min_paym_6_month',
#   'sum_paym_6_month',
#   'bs_ovrl_OMO_CNT_M1',
#   'MV_Traf_3G_d_Mb',
#   'MV_Traf_2G_d_Mb',
#   'MV_dou_innet_out_v',
#   'MV_Traf_omo_inc_v_Min',
#   'MV_dou_net',
#   'MV_dou',
#   'MV_Traf_4G_d_Mb',
#   'MV_Traf_innet_out_v_Min',
#   'MV_Traf_omo_out_v_Min',
#   'MV_net_total',
#   'MV_Traf_Cont_inc_s_Cnt',
#   'MV_dou_4G_d',
#   'MV_Traf_mn_inc_v_Min',
#   'MV_dou_3G_d',
#   'MV_Traf_inc_s_Cnt',
#   'MV_Traf_innet_inc_v_Min',
#   'MV_dou_data',
#   'MV_ARPU',
#   'MV_dou_2G_d',
#   'MV_Traf_ACCA_out_v_Min',
#   'MV_DOU_OT',
#   'abon_id',
#   'call_cnt_out',
#   'call_dur_out',
#   'cnt_sms_out',
#   'cnt_sms_in',
#   'SUM_of_Duration_sec',
#   'SUM_of_Volume_kb',
#   'SUM_of_Count_events',
#   'MAX_of_day_cnt',
#   'missingindicator_bs_count_ppm_mn3',
#   'missingindicator_device_sim_count',
#   'missingindicator_device_days_usage',
#   'missingindicator_device_has_wifi',
#   'missingindicator_device_brand_nan',
#   'missingindicator_device_type_tablet',
#   'missingindicator_device_brand_xiaomi',
#   'missingindicator_imei_mean_price',
#   'missingindicator_device_brand_meizu',
#   'missingindicator_imei_max_price',
#   'missingindicator_device_has_lte',
#   'missingindicator_device_brand_lg',
#   'missingindicator_device_brand_samsung',
#   'missingindicator_device_brand_other',
#   'missingindicator_device_type_nan',
#   'missingindicator_device_type_smartphone',
#   'missingindicator_device_type_rus_other',
#   'missingindicator_imei_mean_day_announced',
#   'missingindicator_device_brand_huawei',
#   'missingindicator_device_brand_apple',
#   'missingindicator_device_width_mm',
#   'missingindicator_device_brand_prestigio',
#   'missingindicator_device_type_module',
#   'missingindicator_device_brand_nokia',
#   'missingindicator_device_type_modem',
#   'missingindicator_device_brand_sony',
#   'missingindicator_device_brand_lenovo',
#   'missingindicator_device_type_phone',
#   'missingindicator_std_paym_6_month',
#   'missingindicator_MV_Traf_Other_inc_v_Min',
#   'missingindicator_MV_dou_Roam'],
#  'xgboost_features': ['num_act_days_min_mnt1',
#   'missingindicator_device_days_usage',
#   'num_act_days_min_mnt3',
#   'num_act_days_mea_mnt1',
#   'voice_in_td_cnt_min_mnt3',
#   'voice_in_td_cnt_min_mnt1',
#   'conn_in_uniq_cnt_mea_wk1',
#   'pay_avg_std_mnt3',
#   'voice_in_tar_dur_mea_wk1',
#   'num_act_days_std_mnt3',
#   'missingindicator_imei_mean_day_announced',
#   'num_act_days_mea_mnt3',
#   'bs_count_ppm_mn3',
#   'voice_mts_out_drest_partmin_mnt3',
#   'voice_out_tar_dur_max_mnt1',
#   'voice_out_tar_dur_mea_wk1',
#   'voice_in_td_cnt_mea_mnt3',
#   'conn_in_uniq_cnt_mea_mnt3',
#   'voice_out_fix_tar_dur_max_mnt3',
#   'pay_sum_std_mnt1',
#   'all_cnt_min_mnt3',
#   'conn_out_uniq_cnt_min_mnt3',
#   'voice_out_fix_tar_dur_std_mnt3',
#   'com_num_part_mea_wk1',
#   'sms_in_cnt_std_mnt3',
#   'loc_is_obl_center',
#   'data_3g_tv_cnt_max_mnt1',
#   'device_days_usage',
#   'loc_market_share',
#   'accum_oth_dur_max_mnt1',
#   'clc_no_vas_roam_min_mnt1',
#   'conn_out_uniq_cnt_mea_wk1',
#   'sms_in_cnt_max_mnt3',
#   'sms_in_cnt_std_mnt1',
#   'device_has_lte',
#   'conn_in_uniq_cnt_std_mnt3',
#   'MV_dou_omo_out_v',
#   'voice_in_tar_dur_mea_mnt1',
#   'days_of_end_last_ppm',
#   'MV_Traf_Cont_out_s_Cnt',
#   'voice_mts_out_nrest_partstd_mnt1',
#   'data_3g_tar_vol_min_mnt3',
#   'MV_Traf_innet_out_s_Cnt',
#   'lt',
#   'sms_in_cnt_min_mnt3',
#   'clc_no_vas_roam_max_mnt1',
#   'device_brand_huawei',
#   'ks_num_part_min_mnt1',
#   'sms_out_cnt_max_mnt1',
#   'content_cnt_mea_mnt3',
#   'MV_Traf_innet_inc_v_Min',
#   'conn_com_part_min_mnt3',
#   'voice_out_td_cnt_max_mnt1',
#   'voice_mts_out_nwork_partmea_mnt1',
#   'vas_clc_mea_mnt1',
#   'ks_num_part_mea_wk1',
#   'voice_out_fix_tar_dur_mea_mnt3',
#   'pay_sum_mea_mnt1',
#   'data_3g_tv_cnt_mea_mnt1',
#   'voice_in_short_part_std_mnt1',
#   'data_3g_dou_mea_mnt1',
#   'data_3g_tv_cnt_td_mnt3',
#   'block_all_dur_td_mnt3',
#   'voice_out_cmpttrs_td_cntmea_mnt3',
#   'voice_mts_in_dwork_part_mea_mnt3',
#   'pay_sum_mea_mnt3',
#   'gprs_tar_vol_mea_mnt1',
#   'sms_clc_std_mnt1',
#   'SUM_of_Volume_kb'],
#  'lgbm_features': ['device_days_usage',
#   'num_act_days_min_mnt3',
#   'num_act_days_min_mnt1',
#   'num_act_days_mea_mnt1',
#   'loc_market_share',
#   'num_act_days_std_mnt3',
#   'lt',
#   'days_of_end_last_ppm',
#   'voice_in_tar_dur_min_mnt3',
#   'voice_in_tar_dur_mea_wk1',
#   'voice_in_tar_dur_min_mnt1',
#   'imei_mean_days_usage',
#   'loc_is_obl_center',
#   'Balance_uah',
#   'num_act_days_mea_mnt3',
#   'all_cnt_std_mnt1',
#   'days_of_last_ppm',
#   'content_cnt_mea_mnt3',
#   'cnt_sms_in',
#   'conn_in_uniq_cnt_mea_mnt3',
#   'all_cnt_min_mnt3',
#   'sms_in_cnt_std_mnt3',
#   'conn_in_uniq_cnt_std_mnt3',
#   'all_cnt_std_mnt3',
#   'non_accum_internet_vol_td_mnt3',
#   'voice_mts_in_dwork_part_mea_mnt3',
#   'abon_id',
#   'voice_in_td_cnt_mea_mnt3',
#   'imei_mean_long_days_usage',
#   'conn_in_uniq_cnt_td_mnt3',
#   'voice_mts_in_dwork_part_std_mnt3',
#   'loc_cnt_events',
#   'voice_in_life_part_std_mnt3',
#   'conn_out_uniq_cnt_mea_wk1',
#   'MAX_of_day_cnt',
#   'all_cnt_mea_wk1',
#   'voice_out_tar_dur_mea_wk1',
#   'MV_Traf_innet_inc_v_Min',
#   'sum_paym_6_month',
#   'device_has_lte',
#   'sms_in_cnt_mea_mnt3',
#   'voice_in_td_cnt_td_mnt3',
#   'imei_mean_day_announced',
#   'pay_max_mea_mnt1',
#   'voice_in_mts_avg_dur_td_mnt3',
#   'count_day_for_last_paym',
#   'num_act_days_std_mnt1',
#   'sms_in_cnt_td_mnt3',
#   'min_paym_6_month',
#   'voice_mts_in_drest_part_std_mnt3',
#   'MV_Traf_Cont_inc_s_Cnt',
#   'voice_in_tar_dur_td_mnt3',
#   'voice_mts_in_dwork_part_td_mnt3',
#   'voice_mts_out_drest_partmea_wk1',
#   'com_num_part_td_mnt3',
#   'voice_mts_out_dwork_partmea_mnt3',
#   'pay_avg_std_mnt3',
#   'sms_in_cnt_std_mnt1',
#   'accum_oth_dur_td_mnt3',
#   'voice_out_short_part_td_mnt3',
#   'content_cnt_td_mnt3',
#   'pay_avg_td_mnt3',
#   'non_accum_internet_vol_min_mnt3',
#   'device_height_mm',
#   'content_cnt_std_mnt1',
#   'data_3g_tv_cnt_td_mnt3',
#   'device_width_mm',
#   'voice_in_cmpttrs_avg_durmea_mnt3',
#   'all_cnt_max_mnt3',
#   'ks_num_part_std_mnt1',
#   'content_cnt_max_mnt3',
#   'voice_in_life_part_td_mnt3',
#   'voice_in_life_part_mea_mnt3',
#   'voice_in_mts_avg_dur_std_mnt3',
#   'voice_in_td_cnt_max_mnt3',
#   'data_3g_tv_cnt_std_mnt1',
#   'data_3g_tv_cnt_std_mnt3',
#   'voice_mts_in_dwork_part_mea_wk1',
#   'vas_clc_td_mnt3',
#   'MV_dou_4G_d',
#   'ks_num_part_td_mnt3',
#   'voice_mts_out_nwork_parttd_mnt3',
#   'conn_in_uniq_cnt_mea_wk1',
#   'voice_in_mts_avg_dur_mea_wk1',
#   'gprs_tar_vol_td_mnt3',
#   'voice_in_td_cnt_std_mnt3',
#   'voice_in_tar_dur_mea_mnt3',
#   'imei_mean_price',
#   'num_act_days_td_mnt3',
#   'SUM_of_Duration_sec',
#   'voice_in_td_cnt_std_mnt1',
#   'all_cnt_max_mnt1',
#   'TM_ID',
#   'MV_dou_innet_out_v',
#   'conn_com_part_td_mnt3',
# ...
#   'voice_in_cmpttrs_avg_durmin_mnt3',
#   'data_3g_tar_vol_mea_mnt1',
#   'ks_num_part_mea_mnt1',
#   'accum_mts_dur_min_mnt1',
#   'all_clc_std_mnt3',
#   'voice_out_cmpttrs_td_cntmin_mnt3',
#   'accum_mts_dur_min_mnt3',
#   'gprs_clc_td_mnt3',
#   'all_home_clc_std_mnt3',
#   'bs_ovrl_OMO_SUM_M1',
#   'sms_clc_mea_mnt3',
#   'pay_p2p_in_sum_max_mnt3',
#   'all_home_clc_mea_mnt3',
#   'device_sim_count',
#   'sms_clc_mea_mnt1',
#   'gprs_clc_max_mnt3',
#   'voice_out_fix_tar_dur_max_mnt1',
#   'voice_in_cmpttrs_avg_durmin_mnt1',
#   'voice_in_life_part_mea_wk1',
#   'clc_no_vas_roam_mea_mnt3',
#   'all_home_clc_max_mnt1',
#   'vas_clc_max_mnt1',
#   'abon_part_std_mnt3',
#   'ks_num_part_mea_wk1',
#   'voice_out_cmpttrs_td_cntmea_mnt1',
#   'gprs_clc_std_mnt3',
#   'clc_no_vas_roam_mea_wk1',
#   'accum_oth_dur_max_mnt3',
#   'call_dur_in',
#   'device_brand_xiaomi',
#   'voice_out_cmpttrs_avg_dumin_mnt3',
#   'voice_mts_out_nrest_partmax_mnt3',
#   'MV_ot_mn_out_v',
#   'MV_ot_omo_out_v',
#   'abon_part_max_mnt3',
#   'accum_oth_dur_mea_wk1',
#   'ks_num_part_min_mnt1',
#   'voice_in_short_part_max_mnt1',
#   'MV_ot_pstn_out_v',
#   'pay_p2p_in_sum_std_mnt1',
#   'pay_avg_max_mnt3',
#   'voice_in_cmpttrs_avg_durmea_mnt1',
#   'device_brand_lenovo',
#   'block_all_dur_mea_mnt3',
#   'MV_dou_out_s',
#   'voice_mts_out_nrest_partmea_mnt1',
#   'MV_ARPU_2G_d_Traf',
#   'voice_out_td_cnt_mea_mnt3',
#   'voice_out_tar_dur_min_mnt3',
#   'ama_volume_mea_mnt3',
#   'MV_Traf_innet_out_s_Cnt',
#   'MV_ARPU_innet_out_s_Traf',
#   'block_all_dur_max_mnt3',
#   'accum_oth_dur_max_mnt1',
#   'com_num_part_max_mnt1',
#   'conn_out_uniq_cnt_min_mnt1',
#   'accum_mts_dur_max_mnt1',
#   'is_max_paym',
#   'conn_in_uniq_cnt_min_mnt1',
#   'MV_ot_4G_d',
#   'device_brand_huawei',
#   'data_3g_dou_min_mnt1',
#   'MV_Traf_mn_out_v_Min',
#   'sms_out_cnt_mea_mnt1',
#   'gprs_clc_mea_mnt3',
#   'voice_in_td_cnt_max_mnt1',
#   'sms_clc_mea_wk1',
#   'MV_dou_Roam',
#   'ama_volume_td_mnt3',
#   'com_num_part_max_mnt3',
#   'conn_out_uniq_cnt_max_mnt3',
#   'voice_mts_out_nrest_partstd_mnt3',
#   'vas_clc_std_mnt1',
#   'voice_mts_in_nwork_part_min_mnt1',
#   'ama_volume_std_mnt3',
#   'MV_dou_Roam_v',
#   'accum_oth_dur_min_mnt1'],
#  'correlation': ['content_cnt_max_mnt1',
#   'voice_out_short_part_max_mnt1',
#   'voice_mts_in_nrest_part_std_mnt1',
#   'num_act_days_max_mnt1',
#   'voice_in_cmpttrs_avg_durmin_mnt1',
#   'com_num_part_mea_mnt1',
#   'pay_avg_mea_mnt1',
#   'voice_out_tar_dur_std_mnt1',
#   'voice_out_tar_dur_min_mnt1',
#   'voice_in_short_part_mea_mnt3',
#   'conn_out_uniq_cnt_std_mnt1',
#   'data_3g_tar_vol_mea_mnt3',
#   'voice_in_tar_dur_max_mnt3',
#   'data_3g_dou_mea_mnt3',
#   'voice_mts_out_drest_partmea_mnt1',
#   'conn_com_part_min_mnt1',
#   'voice_mts_in_dwork_part_mea_wk1',
#   'voice_mts_in_dwork_part_std_mnt1',
#   'voice_in_cmpttrs_avg_durmax_mnt3',
#   'voice_mts_out_nrest_partmax_mnt1',
#   'voice_in_tar_dur_std_mnt1',
#   'voice_mts_out_dwork_partmea_wk1',
#   'voice_in_tar_dur_std_mnt3',
#   'voice_in_td_cnt_max_mnt3',
#   'conn_com_part_std_mnt3',
#   'content_cnt_mea_mnt1',
#   'com_num_part_min_mnt1',
#   'voice_out_td_cnt_mea_mnt1',
#   'com_num_part_max_mnt1',
#   'voice_mts_out_drest_partstd_mnt3',
#   'conn_out_uniq_cnt_std_mnt3',
#   'voice_in_cmpttrs_td_cnt_max_mnt1',
#   'voice_mts_out_nrest_partstd_mnt3',
#   'voice_in_td_cnt_mea_mnt3',
#   'voice_mts_in_nrest_part_mea_wk1',
#   'ks_num_part_mea_wk1',
#   'voice_in_cmpttrs_td_cnt_max_mnt3',
#   'pay_sum_std_mnt1',
#   'conn_in_uniq_cnt_mea_wk1',
#   'voice_in_td_cnt_std_mnt1',
#   'all_cnt_min_mnt1',
#   'voice_in_short_part_max_mnt1',
#   'voice_out_td_cnt_min_mnt1',
#   'data_3g_tar_vol_mea_mnt1',
#   'all_cnt_mea_mnt1',
#   'voice_mts_out_dwork_partstd_mnt1',
#   'pay_sum_max_mnt1',
#   'content_cnt_mea_wk1',
#   'voice_mts_out_nwork_partstd_mnt1',
#   'com_num_part_mea_mnt3',
#   'conn_out_uniq_cnt_max_mnt3',
#   'conn_out_uniq_cnt_mea_mnt3',
#   'conn_com_part_mea_wk1',
#   'com_num_part_max_mnt3',
#   'voice_mts_out_nwork_partmin_mnt1',
#   'pay_avg_std_mnt1',
#   'data_3g_tar_vol_std_mnt1',
#   'voice_in_short_part_max_mnt3',
#   'pay_max_max_mnt1',
#   'pay_max_mea_mnt1',
#   'all_clc_mea_mnt3',
#   'voice_in_kievstar_part_min_mnt1',
#   'voice_mts_in_dwork_part_min_mnt1',
#   'voice_in_cmpttrs_td_cnt_mea_mnt1',
#   'pay_max_mea_mnt3',
#   'ks_num_part_std_mnt1',
#   'voice_in_mts_avg_dur_max_mnt1',
#   'voice_in_td_cnt_mea_mnt1',
#   'voice_mts_in_drest_part_max_mnt3',
#   'voice_out_cmpttrs_avg_dumax_mnt1',
#   'voice_mts_in_nrest_part_mea_mnt3',
#   'voice_out_tar_dur_max_mnt1',
#   'voice_mts_in_drest_part_std_mnt1',
#   'clc_no_vas_roam_std_mnt3',
#   'non_accum_internet_vol_mea_wk1',
#   'voice_mts_out_nwork_partmea_mnt1',
#   'voice_out_cmpttrs_avg_dustd_mnt3',
#   'voice_in_td_cnt_max_mnt1',
#   'voice_in_kievstar_part_std_mnt3',
#   'conn_in_uniq_cnt_max_mnt1',
#   'pay_sum_std_mnt3',
#   'voice_in_cmpttrs_td_cnt_std_mnt1',
#   'voice_out_short_part_mea_mnt3',
#   'data_3g_tar_vol_std_mnt3',
#   'com_num_part_min_mnt3',
#   'conn_out_uniq_cnt_mea_mnt1',
#   'voice_in_cmpttrs_avg_durmea_mnt1',
#   'voice_mts_out_nrest_partmea_mnt3',
#   'non_accum_internet_vol_min_mnt1',
#   'pay_sum_mea_mnt3',
#   'content_cnt_std_mnt1',
#   'voice_out_cmpttrs_td_cntmea_mnt1',
#   'conn_in_uniq_cnt_min_mnt1',
#   'voice_in_tar_dur_mea_mnt3',
#   'conn_out_uniq_cnt_mea_wk1',
#   'voice_out_td_cnt_max_mnt1',
#   'voice_mts_out_drest_partmin_mnt1',
#   'voice_mts_out_dwork_partmea_mnt3',
#   'non_accum_internet_vol_std_mnt1',
#   'voice_out_tar_dur_max_mnt3',
#   'voice_in_life_part_mea_mnt1',
#   'voice_in_cmpttrs_avg_durmea_wk1',
#   'voice_mts_in_drest_part_mea_wk1',
#   'data_3g_dou_mea_wk1',
#   'all_cnt_mea_mnt3',
#   'voice_out_short_part_std_mnt3',
#   'voice_out_tar_dur_mea_wk1',
#   'voice_mts_in_dwork_part_mea_mnt1',
#   'voice_in_kievstar_part_max_mnt3',
#   'clc_no_vas_roam_max_mnt3',
#   'data_3g_dou_max_mnt1',
#   'clc_no_vas_roam_mea_mnt3',
#   'voice_mts_in_nrest_part_max_mnt3',
#   'voice_in_kievstar_part_std_mnt1',
#   'voice_in_mts_avg_dur_min_mnt1',
#   'all_clc_max_mnt1',
#   'conn_in_uniq_cnt_max_mnt3',
#   'voice_out_cmpttrs_avg_dustd_mnt1',
#   'voice_in_tar_dur_mea_mnt1',
#   'voice_mts_in_nwork_part_min_mnt1',
#   'conn_out_uniq_cnt_min_mnt1',
#   'voice_in_cmpttrs_td_cnt_std_mnt3',
#   'voice_mts_out_nwork_partmax_mnt3',
#   'ks_num_part_mea_mnt1',
#   'voice_mts_in_nrest_part_mea_mnt1',
#   'voice_out_short_part_max_mnt3',
#   'voice_mts_out_dwork_partmin_mnt1',
#   'conn_in_uniq_cnt_min_mnt3',
#   'num_act_days_std_mnt3',
#   'voice_mts_in_nwork_part_max_mnt1',
#   'ks_num_part_min_mnt1',
#   'voice_out_td_cnt_mea_wk1',
#   'num_act_days_mea_wk1',
#   'voice_in_cmpttrs_avg_durstd_mnt1',
#   'voice_out_td_cnt_mea_mnt3',
#   'conn_in_uniq_cnt_std_mnt3',
#   'non_accum_internet_vol_max_mnt1',
#   'conn_out_uniq_cnt_min_mnt3',
#   'voice_mts_in_drest_part_mea_mnt1',
#   'content_cnt_mea_mnt3',
#   'voice_mts_out_nrest_partmax_mnt3',
#   'voice_in_mts_avg_dur_mea_mnt3',
#   'voice_mts_out_nwork_partmax_mnt1',
#   'voice_out_cmpttrs_avg_dumea_mnt3',
#   'voice_mts_out_drest_partmax_mnt3',
#   'voice_mts_out_drest_partmea_mnt3',
#   'voice_mts_in_drest_part_min_mnt3',
#   'voice_mts_out_dwork_partmax_mnt3',
#   'ks_num_part_std_mnt3',
#   'pay_avg_max_mnt3',
#   'voice_mts_out_drest_partmax_mnt1',
#   'num_act_days_std_mnt1',
#   'all_cnt_min_mnt3',
#   'voice_in_mts_avg_dur_std_mnt1',
#   'voice_mts_out_drest_partmea_wk1',
#   'voice_in_cmpttrs_td_cnt_mea_mnt3',
#   'voice_out_cmpttrs_avg_dumea_wk1',
#   'voice_out_tar_dur_min_mnt3',
#   'voice_in_tar_dur_min_mnt1',
#   'voice_mts_out_dwork_partmax_mnt1',
#   'voice_mts_out_dwork_partstd_mnt3',
#   'voice_mts_in_drest_part_min_mnt1',
#   'voice_mts_out_drest_partstd_mnt1',
#   'conn_com_part_min_mnt3',
#   'voice_in_td_cnt_std_mnt3',
#   'voice_out_td_cnt_min_mnt3',
#   'voice_mts_out_dwork_partmin_mnt3',
#   'content_cnt_min_mnt1',
#   'voice_mts_in_nwork_part_max_mnt3',
#   'pay_max_std_mnt3',
#   'all_clc_std_mnt1',
#   'ks_num_part_max_mnt1',
#   'data_3g_tar_vol_mea_wk1',
#   'voice_out_cmpttrs_avg_dumax_mnt3',
#   'voice_mts_in_nrest_part_max_mnt1',
#   'voice_mts_in_nrest_part_std_mnt3',
#   'all_cnt_max_mnt1',
#   'voice_in_kievstar_part_max_mnt1',
#   'all_clc_max_mnt3',
#   'conn_in_uniq_cnt_mea_mnt1',
#   'ks_num_part_mea_mnt3',
#   'conn_in_uniq_cnt_std_mnt1',
#   'voice_in_cmpttrs_avg_durmea_mnt3',
#   'voice_mts_in_nwork_part_std_mnt1',
#   'voice_mts_in_dwork_part_min_mnt3',
#   'voice_mts_out_nwork_partmea_mnt3',
#   'voice_in_mts_avg_dur_std_mnt3',
#   'voice_in_kievstar_part_mea_mnt3',
#   'voice_mts_out_nrest_partstd_mnt1',
#   'voice_out_td_cnt_std_mnt1',
#   'voice_mts_in_drest_part_mea_mnt3',
#   'voice_in_cmpttrs_td_cnt_mea_wk1',
#   'voice_mts_in_dwork_part_max_mnt1',
#   'num_act_days_min_mnt3',
#   'voice_mts_in_dwork_part_std_mnt3',
#   'data_3g_dou_mea_mnt1',
#   'non_accum_internet_vol_std_mnt3',
#   'conn_com_part_mea_mnt3',
#   'pay_avg_std_mnt3',
#   'voice_out_cmpttrs_td_cntmax_mnt1',
#   'voice_in_short_part_mea_mnt1',
#   'voice_in_tar_dur_min_mnt3',
#   'data_3g_tar_vol_max_mnt3',
#   'non_accum_internet_vol_min_mnt3',
#   'conn_com_part_std_mnt1',
#   'voice_out_td_cnt_std_mnt3',
#   'voice_out_cmpttrs_avg_dumea_mnt1',
#   'voice_out_cmpttrs_td_cntmea_mnt3',
#   'com_num_part_mea_wk1',
#   'conn_in_uniq_cnt_mea_mnt3',
#   'voice_mts_out_nrest_partmea_wk1',
#   'voice_in_short_part_std_mnt3',
#   'voice_out_cmpttrs_td_cntmax_mnt3',
#   'voice_in_mts_avg_dur_mea_mnt1',
#   'pay_avg_mea_mnt3',
#   'ks_num_part_max_mnt3',
#   'num_act_days_mea_mnt3',
#   'voice_in_mts_avg_dur_max_mnt3',
#   'conn_com_part_max_mnt1',
#   'voice_in_life_part_std_mnt3',
#   'voice_in_short_part_std_mnt1',
#   'num_act_days_mea_mnt1',
#   'content_cnt_max_mnt3',
#   'pay_avg_max_mnt1',
#   'voice_in_kievstar_part_mea_mnt1',
#   'voice_mts_in_dwork_part_mea_mnt3',
#   'voice_in_tar_dur_max_mnt1',
#   'data_3g_tar_vol_max_mnt1',
#   'pay_max_max_mnt3',
#   'content_cnt_std_mnt3',
#   'voice_in_life_part_std_mnt1',
#   'non_accum_internet_vol_max_mnt3',
#   'voice_in_cmpttrs_avg_durmax_mnt1',
#   'voice_in_life_part_max_mnt1',
#   'all_clc_std_mnt3',
#   'voice_in_kievstar_part_mea_wk1',
#   'voice_in_life_part_max_mnt3',
#   'num_act_days_max_mnt3',
#   'voice_mts_in_nwork_part_mea_mnt1',
#   'voice_out_short_part_std_mnt1',
#   'voice_in_tar_dur_mea_wk1',
#   'all_cnt_mea_wk1',
#   'voice_mts_in_nwork_part_mea_wk1',
#   'voice_mts_in_dwork_part_max_mnt3',
#   'voice_mts_out_dwork_partmea_mnt1',
#   'voice_in_mts_avg_dur_mea_wk1',
#   'voice_mts_in_drest_part_max_mnt1',
#   'conn_out_uniq_cnt_max_mnt1',
#   'voice_mts_out_nwork_partmea_wk1',
#   'voice_out_tar_dur_mea_mnt3',
#   'non_accum_internet_vol_mea_mnt1',
#   'voice_in_td_cnt_min_mnt3',
#   'voice_in_td_cnt_min_mnt1',
#   'num_act_days_min_mnt1',
#   'voice_mts_out_nwork_partstd_mnt3',
#   'voice_mts_in_nwork_part_std_mnt3',
#   'pay_max_std_mnt1',
#   'voice_out_td_cnt_max_mnt3',
#   'pay_sum_max_mnt3',
#   'voice_in_td_cnt_mea_wk1',
#   'voice_in_mts_avg_dur_min_mnt3',
#   'voice_mts_out_nrest_partmea_mnt1',
#   'com_num_part_std_mnt1',
#   'voice_mts_in_nwork_part_mea_mnt3',
#   'voice_mts_out_drest_partmin_mnt3',
#   'non_accum_internet_vol_mea_mnt3',
#   'voice_out_tar_dur_std_mnt3',
#   'voice_mts_in_drest_part_std_mnt3',
#   'voice_in_life_part_mea_mnt3',
#   'pay_sum_mea_mnt1',
#   'voice_out_short_part_mea_mnt1',
#   'conn_com_part_mea_mnt1',
#   'voice_in_cmpttrs_avg_durstd_mnt3',
#   'voice_out_tar_dur_mea_mnt1',
#   'conn_com_part_max_mnt3',
#   'com_num_part_std_mnt3',
#   'voice_out_cmpttrs_avg_dumin_mnt1',
#   'all_cnt_max_mnt3',
#   'bs_count_ppm_mn3',
#   'days_of_end_last_ppm',
#   'days_of_last_ppm',
#   'active_ppm',
#   'loc_cnt_events',
#   'device_sim_count',
#   'device_days_usage',
#   'device_has_wifi',
#   'device_has_lte',
#   'device_brand_other',
#   'device_type_smartphone',
#   'device_type_rus_other',
#   'device_width_mm',
#   'device_height_mm',
#   'std_paym_6_month',
#   'max_paym_6_month',
#   'avg_paym_6_month',
#   'cnt_paym_6_month',
#   'last_paym',
#   'sum_paym_6_month',
#   'bs_ovrl_OMO_CNT_M1',
#   'MV_Traf_3G_d_Mb',
#   'MV_dou_innet_out_v',
#   'MV_Traf_omo_inc_v_Min',
#   'MV_dou_net',
#   'MV_dou',
#   'MV_Traf_4G_d_Mb',
#   'MV_Traf_innet_out_v_Min',
#   'MV_Traf_omo_out_v_Min',
#   'MV_Traf_Cont_inc_s_Cnt',
#   'MV_dou_4G_d',
#   'MV_dou_3G_d',
#   'MV_Traf_innet_inc_v_Min',
#   'MV_dou_data',
#   'MV_ARPU',
#   'MV_dou_omo_out_v',
#   'cnt_sms_in',
#   'SUM_of_Volume_kb',
#   'SUM_of_Count_events',
#   'MAX_of_day_cnt',
#   'missingindicator_bs_count_ppm_mn3',
#   'missingindicator_device_sim_count',
#   'missingindicator_device_days_usage',
#   'missingindicator_device_has_wifi',
#   'missingindicator_device_brand_nan',
#   'missingindicator_device_type_tablet',
#   'missingindicator_device_brand_xiaomi',
#   'missingindicator_device_brand_meizu',
#   'missingindicator_device_has_lte',
#   'missingindicator_device_brand_lg',
#   'missingindicator_device_brand_samsung',
#   'missingindicator_device_brand_other',
#   'missingindicator_device_type_nan',
#   'missingindicator_device_type_smartphone',
#   'missingindicator_device_type_rus_other',
#   'missingindicator_device_brand_huawei',
#   'missingindicator_device_brand_apple',
#   'missingindicator_device_width_mm',
#   'missingindicator_device_brand_prestigio',
#   'missingindicator_device_type_module',
#   'missingindicator_device_brand_nokia',
#   'missingindicator_device_type_modem',
#   'missingindicator_device_height_mm',
#   'missingindicator_device_brand_sony',
#   'missingindicator_device_brand_lenovo',
#   'missingindicator_device_type_phone',
#   'missingindicator_std_paym_6_month',
#   'missingindicator_max_paym_6_month',
#   'missingindicator_avg_paym_6_month',
#   'missingindicator_count_day_for_last_paym',
#   'missingindicator_is_max_paym',
#   'missingindicator_cnt_paym_6_month',
#   'missingindicator_is_avg_paym',
#   'missingindicator_last_paym',
#   'missingindicator_min_paym_6_month',
#   'missingindicator_sum_paym_6_month',
#   'missingindicator_bs_ovrl_OMO_SUM_M1',
#   'missingindicator_bs_ovrl_OMO_CNT_M1',
#   'missingindicator_MV_Traf_Cont_out_v_Min',
#   'missingindicator_MV_dou_Roam_v',
#   'missingindicator_MV_dou_out_s',
#   'missingindicator_MV_ARPU_omo_out_s_Traf',
#   'missingindicator_MV_Traf_innet_out_s_Cnt',
#   'missingindicator_MV_ARPU_R_out_v_Traf',
#   'missingindicator_MV_ARPU_mn_out_v_Traf',
#   'missingindicator_MV_ARPU_omo_out_v_Traf',
#   'missingindicator_MV_Traf_Other_out_v_Min',
#   'missingindicator_MV_Traf_R_out_v_Min',
#   'missingindicator_MV_Traf_3G_d_Mb',
#   'missingindicator_MV_Traf_2G_d_Mb',
#   'missingindicator_MV_ARPU_R_out_s_Traf',
#   'missingindicator_MV_dou_Roam_d',
#   'missingindicator_MV_ARPU_Roam_d_Traf',
#   'missingindicator_MV_dou_innet_out_v',
#   'missingindicator_MV_Traf_omo_inc_v_Min',
#   'missingindicator_MV_ARPU_Other_out_v_Traf',
#   'missingindicator_MV_dou_net',
#   'missingindicator_MV_dou',
#   'missingindicator_MV_Traf_Cont_out_s_Cnt',
#   'missingindicator_MV_ARPU_Other_inc_v_Traf',
#   'missingindicator_MV_Traf_4G_d_Mb',
#   'missingindicator_MV_Traf_innet_out_v_Min',
#   'missingindicator_MV_Traf_Other_inc_v_Min',
#   'missingindicator_MV_Traf_omo_out_v_Min',
#   'missingindicator_MV_Traf_pstn_out_v_Min',
#   'missingindicator_MV_net_total',
#   'missingindicator_MV_Traf_Cont_inc_s_Cnt',
#   'missingindicator_MV_Traf_Cont_inc_v_Min',
#   'missingindicator_MV_Traf_Roam_d_Mb',
#   'missingindicator_MV_ARPU_3G_d_Traf',
#   'missingindicator_MV_dou_4G_d',
#   'missingindicator_MV_ARPU_4G_d_Traf',
#   'missingindicator_MV_ARPU_Cont_out_s_Traf',
#   'missingindicator_MV_ARPU_Cont_out_v_Traf',
#   'missingindicator_MV_Traf_R_inc_v_Min',
#   'missingindicator_MV_Traf_mn_inc_v_Min',
#   'missingindicator_MV_dou_3G_d',
#   'missingindicator_MV_ARPU_pstn_out_v_Traf',
#   'missingindicator_MV_ARPU_innet_out_s_Traf',
#   'missingindicator_MV_ARPU_mn_out_s_Traf',
#   'missingindicator_MV_Traf_inc_s_Cnt',
#   'missingindicator_MV_Traf_mn_out_s_Cnt',
#   'missingindicator_MV_ARPU_innet_inc_v_Traf',
#   'missingindicator_MV_Traf_R_out_s_Cnt',
#   'missingindicator_MV_Traf_innet_inc_v_Min',
#   'missingindicator_MV_ARPU_innet_out_v_Traf',
#   'missingindicator_MV_dou_data',
#   'missingindicator_MV_dou_mn_out_v',
#   'missingindicator_MV_ARPU',
#   'missingindicator_MV_dou_omo_out_v',
#   'missingindicator_MV_ARPU_inc_s_Traf',
#   'missingindicator_MV_dou_Roam',
#   'missingindicator_MV_Traf_omo_out_s_Cnt',
#   'missingindicator_MV_dou_2G_d',
#   'missingindicator_MV_Traf_pstn_inc_v_Min',
#   'missingindicator_MV_ARPU_R_inc_v_Traf',
#   'missingindicator_MV_ARPU_2G_d_Traf',
#   'missingindicator_MV_Traf_ACCA_out_v_Min',
#   'missingindicator_MV_Traf_mn_out_v_Min']}

# %%
# dump selected features into file features_scaled.json
import json
with open('Data/features_scaled.json', 'w') as f:
    json.dump(selected_features_over, f)

# %%
import json
# read features from file
with open('Data/features_scaled.json', 'r') as fd:
    feature_sets = json.load(fd)

# %%
for name, features in feature_sets.items():
    print(f'{name}: {len(features)} features')
# Out:
# low_variance_features: 826 features
# k_best_features: 200 features
# features_from_model: 372 features
# xgboost_features: 69 features
# lgbm_features: 526 features
# correlation: 417 features

# %% [markdown]
# Having

# %%
# total_negative_examples / total_positive_example
weight = y_train_stratified[y_train_stratified==0].value_counts().sum() // y_train_stratified[y_train_stratified==1].value_counts().sum()
# Out:
# 14

# %% [markdown]
# weight

# %%
# imbalance dataset
estimators = [
    RandomForestClassifier(random_state=RANDOM_STATE),
    xgb.XGBClassifier(use_label_encoder=False,  random_state=RANDOM_STATE, scale_pos_weight=weight),
    lgb.LGBMClassifier(objective='binary', random_state=RANDOM_STATE, verbose=-1, scale_pos_weight=weight)
]

# %%
# for stratified dataset
select_best_feature_set(
    X_train_stratified, y_train_stratified,
    estimators,
    feature_sets,
)
# Out:
# Dataset: low_variance_features	Model: RandomForestClassifier: Accuracy scores: 0.8086381574793826 	Recall scores: 0.5787822320762434	F1 scores: 0.6157437131999307
# Dataset: k_best_features	Model: RandomForestClassifier: Accuracy scores: 0.7981946213948229 	Recall scores: 0.6098398139708994	F1 scores: 0.6536382929160068
# Dataset: features_from_model	Model: RandomForestClassifier: Accuracy scores: 0.7998514276484616 	Recall scores: 0.5783297922580648	F1 scores: 0.6146517453459981
# Dataset: xgboost_features	Model: RandomForestClassifier: Accuracy scores: 0.81871297233119 	Recall scores: 0.6185439275546565	F1 scores: 0.665685186825274
# Dataset: lgbm_features	Model: RandomForestClassifier: Accuracy scores: 0.8410126293846476 	Recall scores: 0.5919926720235263	F1 scores: 0.6352587903911241
# Dataset: correlation	Model: RandomForestClassifier: Accuracy scores: 0.7979570356605706 	Recall scores: 0.5824684687028514	F1 scores: 0.6201223776303497
# Dataset: low_variance_features	Model: XGBClassifier: Accuracy scores: 0.6645353856252425 	Recall scores: 0.6901060674890935	F1 scores: 0.6760450485825638
# Dataset: k_best_features	Model: XGBClassifier: Accuracy scores: 0.6779301503290764 	Recall scores: 0.7039526582472537	F1 scores: 0.6897250953118955
# Dataset: features_from_model	Model: XGBClassifier: Accuracy scores: 0.6736257730197546 	Recall scores: 0.6833828243191514	F1 scores: 0.6782395595106216
# Dataset: xgboost_features	Model: XGBClassifier: Accuracy scores: 0.6866338679044577 	Recall scores: 0.740695636756761	F1 scores: 0.7090282608408934
# Dataset: lgbm_features	Model: XGBClassifier: Accuracy scores: 0.7060650531182324 	Recall scores: 0.7153518318405294	F1 scores: 0.710458782444651
# Dataset: correlation	Model: XGBClassifier: Accuracy scores: 0.669124841151888 	Recall scores: 0.6897077203453327	F1 scores: 0.6784893967694356
# Dataset: low_variance_features	Model: LGBMClassifier: Accuracy scores: 0.6278664286359668 	Recall scores: 0.7461456679470035	F1 scores: 0.6593329594620093
# Dataset: k_best_features	Model: LGBMClassifier: Accuracy scores: 0.6425856924314267 	Recall scores: 0.7672010483342444	F1 scores: 0.6776577965812465
# Dataset: features_from_model	Model: LGBMClassifier: Accuracy scores: 0.6338479191636053 	Recall scores: 0.7416995288325973	F1 scores: 0.6652589386195572
# Dataset: xgboost_features	Model: LGBMClassifier: Accuracy scores: 0.6528086318076654 	Recall scores: 0.7923941627437834	F1 scores: 0.6915180708213171
# Dataset: lgbm_features	Model: LGBMClassifier: Accuracy scores: 0.6661663523290875 	Recall scores: 0.7829871938550451	F1 scores: 0.7036242251771749
# Dataset: correlation	Model: LGBMClassifier: Accuracy scores: 0.6329884524111644 	Recall scores: 0.7482331977736073	F1 scores: 0.6651973466047648
# For Model: RandomForestClassifier  winner is:  	lgbm_features with score: (0.8410126293846476, 0.5919926720235263, 0.6352587903911241)
# For Model: XGBClassifier  winner is:  	lgbm_features with score: (0.7060650531182324, 0.7153518318405294, 0.710458782444651)
# For Model: LGBMClassifier  winner is:  	lgbm_features with score: (0.6661663523290875, 0.7829871938550451, 0.7036242251771749)
# Dataset Winner is: ('lgbm_features', 3)
# Model winner is: RandomForestClassifier

# %%
# intersection of features
features_intersection = set.intersection(*[set(v) for k,v in feature_sets.items() if k not in ('low_variance_features', 'correlation')])
len(features_intersection)
# Out:
# 16

# %% [markdown]
# SCORES

# %% [markdown]
# ## 4. Model training

# %%
best_features = list(set(feature_sets['lgbm_features']).union(features_intersection))

X_train_fit, X_val_fit, y_train_fit, y_val_fit = train_test_split(X_train[best_features], y_train, test_size=0.2, random_state=RANDOM_STATE, stratify=y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 best_features = list(set(feature_sets['lgbm_features']).union(features_intersection))
# ----> 3 X_train_fit, X_val_fit, y_train_fit, y_val_fit = train_test_split(X_train[best_features], y_train, test_size=0.2, random_state=RANDOM_STATE, stratify=y_train)
#
# NameError: name 'X_train' is not defined

# %%
trained_models = {
    'xgboost': find_params_xgboost(X_train_fit, y_train_fit, scale_pos_weight=weight),
    'rfc': find_params_rfc(X_train_fit, y_train_fit),   
    'lgbmc': find_params_lgbmc(X_train_fit, y_train_fit, lgbmc_kwaNrgs=dict(scale_pos_weight=weight))
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 trained_models = {
# ----> 2     'xgboost': find_params_xgboost(X_train_fit, y_train_fit, scale_pos_weight=weight),
#       3     'rfc': find_params_rfc(X_train_fit, y_train_fit),
#       4     'lgbmc': find_params_lgbmc(X_train_fit, y_train_fit, lgbmc_kwaNrgs=dict(scale_pos_weight=weight))
#       5 }
#
# NameError: name 'X_train_fit' is not defined

# %% [markdown]
# #### Train model specifying  `class_weight` for LightGBMClasifier

# %%
for model in trained_models.values():
    print(f'Model: {model.estimator.__class__.__name__} \tBest score: {model.best_score_}\tValidation score: {model.score(X_val, y_val)}')

# %%
# # let's save models
# import picklef
# with open('Model/trained_models.pcl', 'wb') as fd:
#     pickle.dump(trained_models, fd)

# %%
from joblib import dump, load
# dump(trained_models, 'Model/trained_models.joblib')

# %%
trained_models = load('Model/trained_models.joblib')

# %%
trained_models.keys()
# Out:
# dict_keys(['xgboost', 'rfc', 'lgbmc', 'ensemble', 'lgbmc_imb'])

# %%
y_test.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 y_test.value_counts()
#
# NameError: name 'y_test' is not defined

# %%
# make predictions
# best_features  = list(feature_sets['xgb_column_names'].union(feature_sets['permut_column_names']))


X_test, y_test  = prepare_dataset(df_test_fe, df_test_dpi, df_test_bnum, features=feature_sets['best_features'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 5
#       1 # make predictions
#       2 # best_features  = list(feature_sets['xgb_column_names'].union(feature_sets['permut_column_names']))
# ----> 5 X_test, y_test  = prepare_dataset(df_test_fe, df_test_dpi, df_test_bnum, features=feature_sets['best_features'])
#
# KeyError: 'best_features'

# %%
X_test.shape, y_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 X_test.shape, y_test.shape
#
# NameError: name 'X_test' is not defined

# %%
evaluate_model(trained_models['xgboost'], X_test, y_test, threshold=0.8)

# %%
y_test.value_counts()

# %%
y_test[:10000].value_counts()

# %%
evaluate_model(trained_models['lgbmc'], X_test[:10000], y_test[:10000])

# %%
evaluate_model(trained_models['lgbmc'], X_test, y_test)

# %%
evaluate_model(trained_models['lgbmc'], X_test, y_test, threshold=0.8)
# Out:
# Accuracy: 0.9063066666666667
# F1: 0.46837645634740505
# Precision: 0.3634709094111431
# Recall: 0.6584068914176326
# ROC AUC: 0.7906464352462887
# AUC: 0.8910757275909489
# Classification Report:               precision    recall  f1-score   support
#
#    not churn       0.98      0.92      0.95    140597
#        churn       0.36      0.66      0.47      9403
#
#     accuracy                           0.91    150000
#    macro avg       0.67      0.79      0.71    150000
# weighted avg       0.94      0.91      0.92    150000
#
# ROC Curve: (array([0.        , 0.07711402, 1.        ]), array([0.        , 0.65840689, 1.        ]), array([inf,  1.,  0.]))

# %%
# load model
with open('Model/trained_models.pcl', 'rb') as fd:
    trained_models = pickle.load(fd)

# %%
evaluate_model(trained_models['lgbmc_imb'], X_test, y_test)
# Out:
# Accuracy: 0.9464733333333334
# F1: 0.443010752688172
# Precision: 0.6370710295291301
# Recall: 0.3395724768690843
# ROC AUC: 0.6633173948603549
# AUC: 0.8741229851246646
# Classification Report:               precision    recall  f1-score   support
#
#    not churn       0.96      0.99      0.97    140597
#        churn       0.64      0.34      0.44      9403
#
#     accuracy                           0.95    150000
#    macro avg       0.80      0.66      0.71    150000
# weighted avg       0.94      0.95      0.94    150000
#
# ROC Curve: (array([0.        , 0.01293769, 1.        ]), array([0.        , 0.33957248, 1.        ]), array([inf,  1.,  0.]))

# %%
y_test.value_counts()

# %%
evaluate_model(trained_models['lgbmc_imb'], X_test, y_test, threshold=0.8)

# %% [markdown]
# ### let's create a model amsemble

# %%
evaluate_model(trained_models['ensemble'], X_test, y_test, threshold=0.8)

# %%
evaluate_model(trained_models['ensemble'], X_test, y_test)

# %%
# let's make predictions using weighted ensemble
import numpy as np

def weighted_model_assembly(models, maes, X, y):
    """
    Perform weighted model assembly.

    Parameters:
    models (list): List of pre-trained models
    maes (list): List of Mean Absolute Errors corresponding to the models
    X (numpy.ndarray): Input features for prediction

    Returns:
    numpy.ndarray: Weighted predictions
    """
    # Calculate weights inversely proportional to MAE
    weights = np.array([1.0 / mae for mae in maes])
    weights /= np.sum(weights)  # Normalize weights

    # Initialize an array to store weighted predictions
    preds = np.zeros(X.shape[0])

    # Sum the weighted predictions from each model
    for (_, model), weight in zip(models, weights):
        predictions = model.predict_proba(X)[:, 1]
        preds += weight * predictions
    preds = (preds >= 0.5).astype(int)
    
    print(f'Accuracy: {accuracy_score(y, preds)}')
    print(f'F1: {f1_score(y, preds)}')
    print(f'Precision: {precision_score(y, preds)}')
    print(f'Recall: {recall_score(y, preds)}')
    print(f'ROC AUC: {roc_auc_score(y, preds)}')

    auc_score = roc_auc_score(y, model.predict_proba(X)[:,1])
    cm = confusion_matrix(y, preds, labels=model.classes_)
    print(f'AUC: {auc_score}')
    print(f'Classification Report: {classification_report(y, preds, target_names=["not churn", "churn"])}')
    print(f'ROC Curve: {roc_curve(y, preds)}')


    
    # Plot confusion matrix

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot()
    plt.show()

    # TP, FP, FN, TN = cm.ravel()
    # return TP, FP, FN, TN



def evaluate_models(models, X_train, X_val, y_train, y_val):
    # fit and evaluate the models
    scores = list()
    for name, model in models:
        # fit the model
        # model.fit(X_train, y_train)
        # evaluate the model
        yhat = model.predict(X_val)
        mae = mean_absolute_error(y_val, yhat)
        # store the performance
        scores.append(-mae)
        # report model performance
    return scores

# %%
X_train.shape, y_train.shape

# %%
models  = [
    ('xgboost', trained_models['xgboost']),
    ('lgbmc', trained_models['lgbmc']),
    ('rfc', trained_models['rfc']),
    ('lgbmc_imb', trained_models['lgbmc_imb'])

]
scores = evaluate_models(models, X_train_stratified, X_val_stratified, y_train_stratified, y_val_stratified)
# weighted_ensemble(trained_models, X_test, y_test)

# %%
original_scores = scores.copy()
scores[1] = 0.5

# %%
y_test[:1000].value_counts()

# %%
# select 100 rows from X_test

weighted_model_assembly(models, scores.values(), X_test[:1000], y_test[:1000])

# %%
# select 100 rows from X_test

weighted_model_assembly(models, scores, X_test[100:], y_test[100:])

# %%
weighted_model_assembly(models, scores, X_test[100:], y_test[100:])

# %%
import optuna
import numpy as np

def objective(trial):
    # Suggest weights for each model
    weights = [trial.suggest_float(f'weight_{i}', 0, 1) for i in range(len(models))]
    weights = np.array(weights) / np.sum(weights)  # Normalize weights
    
    # Get confusion matrix components
    TP, FP, FN, TN = weighted_model_assembly(models, weights, X_test[1000:], y_test[1000:])
    
    # Define the optimization target
    # We want to maximize TP and TN, and minimize FP and FN
    score = TP + TN - FP - FN
    
    return -score  # Optuna minimizes the objective function, so negate the score

# Optimize weights
study = optuna.create_study()
study.optimize(objective, n_trials=100)

# Get the best weights
best_weights = study.best_trial.params
print("Best weights: ", best_weights)

# %%
scores = {'weight_0': 0.9270322257214373, 'weight_1': 0.8629088399223556, 'weight_2': 0.754293288527458, 'weight_3': 0.07091431790704351}

# %%
weighted_model_assembly(models, list(scores.values()), X_test[100:], y_test[100:])

# %%
y_test.value_counts()

# %% [markdown]
# ## features after EDA

# %%
# load  single value features]
import json
with open(r'Data/features_high_single_ratio.json', 'r') as f:
    features_single = json.load(f)

# %%
# create a function to apply np log to the set of fetures and return the result  as a dataframe  and avoid inf values
def apply_log1p_to_features(X: pd.DataFrame, features: list[str]) -> pd.DataFrame:
    """
    Apply log1p to features
    """
    return X[features].apply(np.log1p)
